# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from sklearn.feature_selection import mutual_info_regression
from sklearn.neighbors import KernelDensity
from scipy.stats import multivariate_normal
from scipy.special import logsumexp
from scipy import linalg
import scipy.integrate as integrate
from scipy.special import gamma
import time

from sklearn.mixture import GaussianMixture as GMM
from sklearn.mixture._gaussian_mixture import _estimate_log_gaussian_prob, _compute_precision_cholesky, _estimate_gaussian_covariances_full
from sklearn.utils import check_random_state
from sklearn import cluster
from sklearn.model_selection import KFold

import pandas as pd
from astropy.stats import sigma_clip

# %%
class my_GMM(GMM):
    """
    Custom GMM class based on the sklearn GMM class.
    This allows to work with a GMM with fixed parameters, without fitting it.
    It also allows to estimate MI with a certain number of MC samples.
    The different initialisation types are dealt with separately.
    """
    def __init__(self,
                 n_components=1,
                 covariance_type="full",
                 tol=1e-5,
                 reg_covar=1e-6,
                 max_iter=100,
                 n_init=1,
                 init_params="random",
                 random_state=None,
                 warm_start=False,
                 verbose=0,
                 verbose_interval=10,
                 weights_init=None,
                 means_init=None,
                 precisions_init=None,
                 covariances_init=None
                 ):
        super(my_GMM, self).__init__(n_components=n_components,
                 covariance_type=covariance_type,
                 tol=tol,
                 reg_covar=reg_covar,
                 max_iter=max_iter,
                 n_init=n_init,
                 init_params=init_params,
                 random_state=random_state,
                 warm_start=warm_start,
                 verbose=verbose,
                 verbose_interval=verbose_interval,
                 weights_init=weights_init,
                 means_init=means_init,
                 precisions_init=precisions_init,
                )

        self.means_ = means_init
        self.covariances_ = covariances_init
        self.covariances_init = covariances_init
        self.weights_ = weights_init
        #self.random_state = random_state
        #self.covariance_type = covariance_type
        #self.precisions_cholesky_ = _compute_precision_cholesky(
        #        self.covariances_, self.covariance_type
        #    )


    def score_samples(self, X):
        """Compute the log-likelihood of each sample.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            List of n_features-dimensional data points. Each row
            corresponds to a single data point.
        Returns
        -------
        log_prob : array, shape (n_samples,)
            Log-likelihood of each sample in `X` under the current model.
        """
        #check_is_fitted(self)
        #X = self._validate_data(X, reset=False)

        return logsumexp(self._estimate_weighted_log_prob(X), axis=1)

    def predict(self, X):
        """Predict the labels for the data samples in X using trained model.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            List of n_features-dimensional data points. Each row
            corresponds to a single data point.
        Returns
        -------
        labels : array, shape (n_samples,)
            Component labels.
        """
        #check_is_fitted(self)
        #X = self._validate_data(X, reset=False)
        return self._estimate_weighted_log_prob(X).argmax(axis=1)

    def predict_proba(self, X):
        """Evaluate the components' density for each sample.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            List of n_features-dimensional data points. Each row
            corresponds to a single data point.
        Returns
        -------
        resp : array, shape (n_samples, n_components)
            Density of each Gaussian component for each sample in X.
        """
        # copied here to remove the fitting check
        #check_is_fitted(self)
        #X = self._validate_data(X, reset=False)
        _, log_resp = self._estimate_log_prob_resp(X)
        return np.exp(log_resp)

    def sample(self, n_samples=1):
        """Generate random samples from the fitted Gaussian distribution.
        Parameters
        ----------
        n_samples : int, default=1
            Number of samples to generate.
        Returns
        -------
        X : array, shape (n_samples, n_features)
            Randomly generated sample.
        y : array, shape (nsamples,)
            Component labels.
        """
        # copied here to remove the fitting check
        # check_is_fitted(self)

        if n_samples < 1:
            raise ValueError(
                "Invalid value for 'n_samples': %d . The sampling requires at "
                "least one sample." % (self.n_components)
            )

        _, n_features = self.means_.shape
        rng = check_random_state(self.random_state)
        n_samples_comp = rng.multinomial(n_samples, self.weights_)

        if self.covariance_type == "full":
            X = np.vstack(
                [
                    rng.multivariate_normal(mean, covariance, int(sample))
                    for (mean, covariance, sample) in zip(
                        self.means_, self.covariances_, n_samples_comp
                    )
                ]
            )
        elif self.covariance_type == "tied":
            X = np.vstack(
                [
                    rng.multivariate_normal(mean, self.covariances_, int(sample))
                    for (mean, sample) in zip(self.means_, n_samples_comp)
                ]
            )
        else:
            X = np.vstack(
                [
                    mean + rng.randn(sample, n_features) * np.sqrt(covariance)
                    for (mean, covariance, sample) in zip(
                        self.means_, self.covariances_, n_samples_comp
                    )
                ]
            )

        y = np.concatenate(
            [np.full(sample, j, dtype=int) for j, sample in enumerate(n_samples_comp)]
        )

        return (X, y)

    def score_samples_marginal(self, X, index=0):
        """Compute the log-likelihood of each sample for the marginal model, indexed by either 0 (x) or 1 (y).
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            List of n_features-dimensional data points. Each row
            corresponds to a single data point.
        index: integer
            Either 0 (marginal x) or 1 (marginal y).
        Returns
        -------
        log_prob : array, shape (n_samples,)
            Log-likelihood of each sample in `X` under the current model.
        """

        oned_cholesky = np.sqrt(1/self.covariances_[:, index, index]).reshape(-1, 1, 1)
        marginal_logprob = _estimate_log_gaussian_prob(
            X, self.means_[:, index].reshape(-1, 1), oned_cholesky, self.covariance_type
        )

        return logsumexp(np.log(self.weights_) + marginal_logprob, axis=1)


    def estimate_MI_MC(self, MC_samples=100):
        """
        Compute the mutual information (MI) associated with a particular GMM model, using MC integration
        Parameters
        ----------
        MC_samples : integer
            Number of Monte Carlo samples to perform numerical integration of the MI integral.
        Returns
        ----------
        MI : integer
            The value of mutual information.
        -------
        """
        # sample MC samples
        points, clusters = self.sample(MC_samples)
        
        # we first evaluate the log-likelihood for the joint probability
        joint = self.score_samples(points)

        # we then evaluate the marginals; index=0 corresponds to x, index=y corresponds to y
        marginal_x = self.score_samples_marginal(points[:, :1], index=0)
        marginal_y = self.score_samples_marginal(points[:, 1:], index=1)

        MI = np.mean(joint - marginal_x - marginal_y)
        return MI
    
    def fit_predict(self, X, y=None):
        """Estimate model parameters using X and predict the labels for X.
        The method fits the model n_init times and sets the parameters with
        which the model has the largest likelihood or lower bound. Within each
        trial, the method iterates between E-step and M-step for `max_iter`
        times until the change of likelihood or lower bound is less than
        `tol`, otherwise, a :class:`~sklearn.exceptions.ConvergenceWarning` is
        raised. After fitting, it predicts the most probable label for the
        input data points.
        .. versionadded:: 0.20
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            List of n_features-dimensional data points. Each row
            corresponds to a single data point.
        y : Ignored
            Not used, present for API consistency by convention.
        Returns
        -------
        labels : array, shape (n_samples,)
            Component labels.
        """
        X = self._validate_data(X, dtype=[np.float64, np.float32], ensure_min_samples=2)
        if X.shape[0] < self.n_components:
            raise ValueError(
                "Expected n_samples >= n_components "
                f"but got n_components = {self.n_components}, "
                f"n_samples = {X.shape[0]}"
            )
        self._check_initial_parameters(X)

        # if we enable warm_start, we will have a unique initialisation
        do_init = not (self.warm_start and hasattr(self, "converged_"))
        n_init = self.n_init if do_init else 1

        max_lower_bound = -np.inf
        self.converged_ = False

        random_state = check_random_state(self.random_state)

        n_samples, _ = X.shape
        for init in range(n_init):
            self._print_verbose_msg_init_beg(init)

            if do_init:
                self._initialize_parameters(X, random_state)

            lower_bound = -np.inf if do_init else self.lower_bound_

            for n_iter in range(1, self.max_iter + 1):
                #if n_iter==179:
                #    try:
                #        #print(n_iter)
                #        print(np.linalg.eig(self.covariances_[2]))
                #        #print(self.means_[2])
                #        #ind = np.argsort(log_resp[:, 2])[-5:]
                #        #print(X[ind])
                #        #print(log_resp[np.argmax(log_resp[:, 2])])
                #        #plt.hist(log_resp[:, 4])
                #    except:
                #        pass

                prev_lower_bound = lower_bound

                log_prob_norm, log_resp = self._e_step(X)
                self._m_step(X, log_resp)
                lower_bound = self._compute_lower_bound(log_resp, log_prob_norm)

                change = lower_bound - prev_lower_bound
                self._print_verbose_msg_iter_end(n_iter, change)

                if abs(change) < self.tol:
                    self.converged_ = True
                    break

            self._print_verbose_msg_init_end(lower_bound)

            if lower_bound > max_lower_bound or max_lower_bound == -np.inf:
                max_lower_bound = lower_bound
                best_params = self._get_parameters()
                best_n_iter = n_iter

        if not self.converged_:
            warnings.warn(
                "Initialization %d did not converge. "
                "Try different init parameters, "
                "or increase max_iter, tol "
                "or check for degenerate data." % (init + 1),
                ConvergenceWarning,
            )

        self._set_parameters(best_params)
        self.n_iter_ = best_n_iter
        self.lower_bound_ = max_lower_bound

        # Always do a final e-step to guarantee that the labels returned by
        # fit_predict(X) are always consistent with fit(X).predict(X)
        # for any value of max_iter and tol (and any random_state).
        _, log_resp = self._e_step(X)

        return log_resp.argmax(axis=1)

# %%
# now we also focus on initialising the GMM parameters
# we provide four different initialisation types, which return weights, means and covs
# these will go as input into the GMM class, so that we can ignore whatever happens there

  
def initialize_parameters(X, random_state, n_components=1, s=None, reg_covar=1e-6, init_type='random'):
    """Initialize the model parameters.
    Parameters
    ----------
    X : array-like of shape  (n_samples, n_features)
    random_state : RandomState
        A random number generator instance that controls the random seed used for the method chosen to initialize the parameters.
    n_components: int
        Number of components of the GMM to fit.
    s : float
        If set, sets component variances in the 'random' and 'minmax' cases. 
        If s is not given, it will be set such that the volume of all components
        completely fills the space covered by data.
    init_type : {'random', 'minmax', 'kmeans', 'random_sklearn', 'kmeans_sklearn'}, default='random'
        The method used to initialize the weights, the means and the
        precisions.
        Must be one of:
            'random': weights are set uniformly, covariances are proprtional to identity (with prefactor s^2). 
            For each mean, a data sample is selected at random, and a multivariant Gaussian with variance s^2 offset is added.
            'minmax': same as above, but means are distributed randomly over the range that is covered by data.
            'kmeans': k-means clustering run as in Algorithm 1 from Bloemer & Bujna (arXiv:1312.5946), as implemented by Melchior & Goulding (arXiv:1611.05806)
             WARNING: The result of this call are not deterministic even if rng is set because scipy.cluster.vq.kmeans2 uses its own initialization. 
             TO DO: require scipy > 1.7, and include "seed=random_state" in the kmeans call
            'kmeans_sklearn' : responsibilities are initialized using kmeans.
            'random_sklearn' : responsibilities are initialized randomly.
    reg_covar : float
        The regularization added to the diagonal of the covariance matrices.
    Returns
    ----------
    weights : array, shape (n_components, 1)
        The initial weights of the GMM model.
    means : array, shape (n_components, n_features)
        The initial means of the GMM model.        
    covariances : array, shape (n_components, n_features, n_features)
        The initial covariance matrices of the GMM model.        
    """
    n_samples, n_dim = X.shape

    random_state = check_random_state(random_state)
    if s is None and (init_type=='random' or init_type=='minmax'):
        min_pos = X.min(axis=0)
        max_pos = X.max(axis=0)
        vol_data = np.prod(max_pos-min_pos)
        s = (vol_data / n_components * gamma(n_dim*0.5 + 1))**(1/n_dim) / np.sqrt(np.pi)
        print(f"Scale s set to s={s:.2f}...")

    if init_type == "random":

        weights = np.repeat(1/n_components, n_components)
        # initialize components around data points with uncertainty s
        refs = random_state.randint(0, n_samples, size=n_components)

        means = X[refs] + random_state.multivariate_normal(np.zeros(n_dim), s**2 * np.eye(n_dim), size=n_components)
        
        covariances = np.repeat(s**2 * np.eye(n_dim)[np.newaxis, :, :], n_components, axis=0)

    elif init_type == "minmax":

        weights = np.repeat(1/n_components, n_components)

        min_pos = X.min(axis=0)
        max_pos = X.max(axis=0)
        means = min_pos + (max_pos-min_pos)*random_state.rand(n_components, n_dim)
        
        covariances = np.repeat(s**2 * np.eye(n_dim)[np.newaxis, :, :], n_components, axis=0)

    elif init_type == 'kmeans':
        from scipy.cluster.vq import kmeans2
        center, label = kmeans2(X, n_components)
        weights = np.zeros(n_components)
        means = np.zeros((n_components, n_dim))
        covariances = np.zeros((n_components, n_dim, n_dim))

        for k in range(n_components):
            mask = (label == k)
            weights[k] = mask.sum() / len(X)
            means[k,:] = X[mask].mean(axis=0)
            d_m = X[mask] - means[k,:] 
            # funny way of saying: for each point i, do the outer product
            # of d_m with its transpose and sum over i
            covariances[k,:,:] = (d_m[:, :, None] * d_m[:, None, :]).sum(axis=0) / len(X)

    elif init_type == "random_sklearn":
        resp = random_state.rand(n_samples, n_components)
        resp /= resp.sum(axis=1)[:, np.newaxis]
        nk = resp.sum(axis=0) + 10 * np.finfo(resp.dtype).eps
        
        weights = nk/n_samples
        means = np.dot(resp.T, X) / nk[:, np.newaxis]
        covariances = _estimate_gaussian_covariances_full(resp, X, nk, means, reg_covar)

    elif init_type == "kmeans_sklearn":
        resp = np.zeros((n_samples, n_components))
        label = (
            cluster.KMeans(
                n_clusters=n_components, n_init=1, random_state=random_state
            )
            .fit(X)
            .labels_
        )
        resp[np.arange(n_samples), label] = 1
        nk = resp.sum(axis=0) + 10 * np.finfo(resp.dtype).eps
        
        weights = nk/n_samples
        means = np.dot(resp.T, X) / nk[:, np.newaxis]
        covariances = _estimate_gaussian_covariances_full(resp, X, nk, means, reg_covar)

    else:
        # TO DO: raise error instead of just priting it
        print("Error: initalisation type not specified or not known; it should be one of 'random', 'minmax', 'kmeans', 'random_sklearn', 'kmeans_sklearn'")
        
    precisions = np.empty_like(covariances)
    for i in range(n_components):
        precisions[i] = np.linalg.inv(covariances[i])
        
    return weights, means, covariances, precisions

# %%
def MI_procedure_diffconvergence(X, n_components=1, n_folds=5, n_inits=5, init_type='random', reg_covar=1e-6, tol=1e-6):
    """
    Docstring TO DO
    """
    initial_time = time.time()
    # this will be used to store mean validation log-likelihood 
    val_scores_seeds = np.zeros(n_inits)
    train_scores_seeds = np.zeros(n_inits)

    # prepare the folds; note the splitting will be the same for all initialisations
    # the random seed is fixed here, but results should be independent of the exact split
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)

    # fix the random seed first
    for r in range(n_inits):

        w_init, m_init, c_init, p_init = initialize_parameters(X, r, n_components=n_components, init_type=init_type)
        validation_scores = []
        training_scores = []
        
        for train_indices, valid_indices in kf.split(X):
            X_training = X[train_indices]
            X_validation = X[valid_indices]
            
            fitted_gmm = my_GMM(n_components=n_components, reg_covar=reg_covar, 
                            tol=tol, max_iter=10000, 
                            random_state=r, weights_init=w_init, 
                            means_init=m_init, precisions_init=p_init).fit(X_training)

            # we take the mean logL per sample, since folds might have slightly different sizes
            val_score = fitted_gmm.score_samples(X_validation).mean()
            train_score = fitted_gmm.score_samples(X_training).mean()

            #print(val_score)
            validation_scores.append(np.copy(val_score))
            training_scores.append(np.copy(train_score))


        # take mean of current seed's val scores
        val_scores_seeds[r] = np.mean(validation_scores)
        train_scores_seeds[r] = np.mean(training_scores)

        #print()
        
    # select seed with highest val score
    best_seed = np.argmax(val_scores_seeds)
    best_val_score = np.max(val_scores_seeds)
    best_train_score = np.max(train_scores_seeds)
    
    return best_seed, best_val_score, best_train_score

# %% [markdown]
# ### Let's look at MI

# %%
codes_file = 'encoded_harps_unique_128d_e182_i1500000.npy'
codes = pd.DataFrame(np.load(codes_file))

labels = pd.read_csv('harps_metadata_and_labels.csv')

#--- If looking at the 'unique' subset, drop unnecessary rows
if "unique" in codes_file:
    labels.dropna(subset=['unique_subset'],inplace=True)

#--- and reindex the codes dataframe accordingly
codes.loc[:,'dp_id'] = labels['dp_id'].values
labels = labels.set_index('dp_id')
codes = codes.set_index('dp_id')

# %%
from sklearn.feature_selection import mutual_info_regression
significant_dimensions = [ 11,  19,  58,  85,  99, 124]
stellar_params = ['radvel','Teff','Mass','[M/H]','airmass','snr','vsini']
MIs = np.zeros([len(stellar_params), \
                    len(significant_dimensions)])
codes_sig = codes.iloc[:, significant_dimensions]
                
for li,stellar_param in enumerate(stellar_params):        
    label = labels.loc[:,stellar_param].values
    
    ind_mask = ~np.isnan(label)
    label_ = sigma_clip(label,sigma=5,masked=True)

    ind_mask = ind_mask & (~label_.mask)
    label_ = label_.data[ind_mask]      
    for i in range(0,codes_sig.shape[1]):                          
        codes_ = codes_sig.iloc[:,i].values
        codes_ = codes_[ind_mask]
        
        MIs[li,i] = mutual_info_regression(codes_.reshape(-1, 1),label_)
# Out:
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]

# %%
import seaborn as sns

plt.figure()
ax = sns.heatmap(MIs, annot=True, cmap='Blues')
ax.yaxis.set_ticklabels(stellar_params)
ax.xaxis.set_ticklabels(significant_dimensions)
plt.gcf().set_facecolor('white')

# %% [markdown]
# ### Now use our approach

# %%
n_inits = 5
n_folds = 3
init_type = 'random_sklearn'
n_bootstrap = 100
MC_samples = 1e5
tol = 1e-5
reg_covar = 1e-13
components_range = 200
        
MI_all = np.zeros((len(stellar_params), 128, n_bootstrap))

for li,stellar_param in enumerate(stellar_params):
    if li <= 2:
        continue
    label = labels.loc[:,stellar_param].values
    
    ind_mask = ~np.isnan(label)
    label_ = sigma_clip(label,sigma=5,masked=True)

    ind_mask = ind_mask & (~label_.mask)
    samples1 = label_.data[ind_mask]    

    for latbin2 in range(128):
        codes_ = codes.iloc[:,latbin2].values
        samples2 = codes_[ind_mask]

        X = np.stack((samples1, samples2), axis=0).T

        # now we do this for many components, from 1 to 15

        all_MI_estimates = np.zeros((components_range, n_bootstrap))

        best_val = -np.inf

        initial_time = time.time()
        for n_components in range(1, components_range+1):
            current_seed, current_val, _ = MI_procedure_diffconvergence(X, n_components=n_components, n_folds=n_folds, 
                                                               init_type=init_type, n_inits=n_inits, tol=tol, reg_covar=reg_covar)

            # check if convergence has been reached based on val score
            if current_val > best_val:
                best_val = current_val
                best_seed = current_seed
                print(n_components, best_val)
            else:
                # if val score has not increased, then we should stop and calculate MI with the previous parameters
                best_components = n_components-1
                print(f'Convergence reached at {best_components} components') 
                w_init, m_init, c_init, p_init = initialize_parameters(X, best_seed, n_components=best_components, init_type=init_type)
                MI_estimates = np.zeros(n_bootstrap)

                # bootstrap available samples
                for i in range(n_bootstrap):
                    # we use i to change the seed so that the results will be fully reproducible
                    rng = np.random.default_rng(i)
                    X_bs = rng.choice(X, X.shape[0])
                    gmm = my_GMM(n_components=best_components, reg_covar=reg_covar, 
                                tol=tol, max_iter=10000, 
                                random_state=best_seed, weights_init=w_init, 
                                means_init=m_init, precisions_init=p_init).fit(X_bs)

                    # in case of "warm start", uncomment next line
                    #w_init, m_init, c_init, p_init = gmm.weights_, gmm.means_, gmm.covariances_, gmm.precisions_

                    current_MI_estimate = gmm.estimate_MI_MC(MC_samples=MC_samples)
                    MI_estimates[i] = current_MI_estimate
                break

        print(f'Total time to run the procedure: {time.time()-initial_time:.2f} s')
        print()
        MI_all[li, latbin2] = MI_estimates
        print(li, latbin2, np.mean(MI_estimates), np.std(MI_estimates))
        print()
# Out:
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# 1 3.3743374841168907
# 2 3.476806573822877
# 3 3.5052990536617874
# 4 3.5184776348256435
# 5 3.5186138204312645
# Convergence reached at 5 components
# Total time to run the procedure: 62.56 s
#
# 3 0 0.017540854380067892 0.005223787121020774
#
# 1 3.5565183098297717
# 2 3.646088339765779
# 3 3.660486514412544
# 4 3.6640268125432205
# 5 3.66649326112112
# Convergence reached at 5 components
# Total time to run the procedure: 59.86 s
#
# 3 1 0.047516159273999 0.008540405915673328
#
# 1 3.8373867623217746
# 2 3.9153754133662964
# 3 3.924117146828235
# Convergence reached at 3 components
# Total time to run the procedure: 30.21 s
#
# 3 2 0.01765620497313895 0.004066600932975267
#
# 1 3.584322272677145
# 2 3.668810989746358
# 3 3.6712914758452446
# Convergence reached at 3 components
# Total time to run the procedure: 27.61 s
#
# 3 3 0.039227028511894 0.005842250863764004
#
# 1 3.864130044396555
# 2 4.018504761194466
# 3 4.087146350609209
# 4 4.1071063747389465
# 5 4.118298715702063
# Convergence reached at 5 components
# Total time to run the procedure: 48.94 s
#
# 3 4 0.025575655828196764 0.007783790789230784
#
# 1 3.245482900212807
# 2 3.3390014964338346
# 3 3.347486073782374
# Convergence reached at 3 components
# Total time to run the procedure: 24.47 s
#
# 3 5 0.042265527198587755 0.006823344958818069
#
# 1 3.602583663778883
# 2 3.701359103516193
# 3 3.707624728489599
# 4 3.710141002956025
# 5 3.7119642881623247
# Convergence reached at 5 components
# Total time to run the procedure: 81.85 s
#
# 3 6 0.03594139030152283 0.005802251110692932
#
# 1 3.155150519852698
# 2 3.2906861457130305
# 3 3.326960146836953
# 4 3.3293986744170057
# Convergence reached at 4 components
# Total time to run the procedure: 44.00 s
#
# 3 7 0.03932211842261466 0.008291278564661381
#
# 1 3.7122042148222163
# 2 3.8241068564006753
# 3 3.8315026299192607
# 4 3.8450113067108256
# 5 3.8459475079079755
# Convergence reached at 5 components
# Total time to run the procedure: 72.49 s
#
# 3 8 0.03983124177702739 0.0077935817940143004
#
# 1 3.005987674359892
# 2 3.094470679915886
# 3 3.1369636426791963
# Convergence reached at 3 components
# Total time to run the procedure: 23.85 s
#
# 3 9 0.03004998072954162 0.0079306475191324
#
# 1 3.503871399098649
# 2 3.6239694310494515
# 3 3.6374776306431165
# 4 3.654093251742251
# 5 3.6628212963806432
# Convergence reached at 5 components
# Total time to run the procedure: 62.09 s
#
# 3 10 0.09731896069406559 0.011476804579520978
#
# 1 -1.2451329301723784
# 2 -1.0688342417750278
# 3 -1.012387211355603
# 4 -0.9911437668082167
# Convergence reached at 4 components
# Total time to run the procedure: 33.48 s
#
# 3 11 0.10529299912599457 0.010987516600655077
#
# 1 3.220996628507456
# 2 3.298514240937797
# 3 3.3154429380945616
# 4 3.321210017514092
# Convergence reached at 4 components
# Total time to run the procedure: 47.37 s
#
# 3 12 0.019471932656619017 0.005309406702132279
#
# 1 3.210883068036509
# 2 3.2905620226540684
# 3 3.31239425261337
# 4 3.3208513730148117
# Convergence reached at 4 components
# Total time to run the procedure: 39.45 s
#
# 3 13 0.03925018753577607 0.007059467497070592
#
# 1 3.3273573538455126
# 2 3.431436546434607
# 3 3.440361360922528
# 4 3.4484512650155406
# Convergence reached at 4 components
# Total time to run the procedure: 55.13 s
#
# 3 14 0.023037991587437946 0.006256240834210116
#
# 1 3.40297475417578
# 2 3.5135785905214085
# 3 3.551105113965716
# 4 3.5565113742002654
# 5 3.5577974605327083
# Convergence reached at 5 components
# Total time to run the procedure: 52.83 s
#
# 3 15 0.023718678802810714 0.005671278721310549
#
# 1 3.204569392878455
# 2 3.3143646524371593
# 3 3.357255549668499
# 4 3.3794296364016945
# 5 3.388085142427238
# Convergence reached at 5 components
# Total time to run the procedure: 64.22 s
#
# 3 16 0.028160760408536527 0.006412917354784928
#
# 1 3.6385784946667017
# 2 3.7380746415830663
# 3 3.774679124030717
# Convergence reached at 3 components
# Total time to run the procedure: 25.98 s
#
# 3 17 0.018421192772790224 0.004091842247759328
#
# 1 3.6852665305783403
# 2 3.762466444205265
# 3 3.7762544588311564
# 4 3.777992053616631
# 5 3.78311655726462
# Convergence reached at 5 components
# Total time to run the procedure: 68.04 s
#
# 3 18 0.03857410460627688 0.0065852789942557706
#
# 1 -0.7594976663663647
# 2 -0.4735423769495061
# 3 -0.41018143055587614
# 4 -0.3873571498784383
# 5 -0.3813624809879392
# 6 -0.3746371298974074
# Convergence reached at 6 components
# Total time to run the procedure: 60.52 s
#
# 3 19 0.0414312820232687 0.006780588401264269
#
# 1 3.493482000098126
# 2 3.6045384573620987
# 3 3.641742344000899
# Convergence reached at 3 components
# Total time to run the procedure: 26.76 s
#
# 3 20 0.024641373333765385 0.004670642405091967
#
# 1 3.283742515215263
# 2 3.369837103037259
# 3 3.3885684975746195
# Convergence reached at 3 components
# Total time to run the procedure: 33.61 s
#
# 3 21 0.04801004027029087 0.008353456258114607
#
# 1 3.4730940626135207
# 2 3.549363748804923
# 3 3.6005080869040413
# Convergence reached at 3 components
# Total time to run the procedure: 27.50 s
#
# 3 22 0.026668193060627458 0.005548328101257651
#
# 1 3.3148364291369607
# 2 3.396595078674705
# Convergence reached at 2 components
# Total time to run the procedure: 18.66 s
#
# 3 23 0.006519187609200664 0.0020891366619162797
#
# 1 3.362261480990608
# 2 3.4458663049103104
# 3 3.459470826192638
# 4 3.485198791676753
# 5 3.4864367394094877
# Convergence reached at 5 components
# Total time to run the procedure: 64.87 s
#
# 3 24 0.03127621892476765 0.006081272274513767
#
# 1 3.308011543999146
# 2 3.4116434417429873
# 3 3.4263206961952157
# 4 3.43784867902524
# 5 3.4387489804453417
# Convergence reached at 5 components
# Total time to run the procedure: 57.66 s
#
# 3 25 0.0522035870031382 0.007511499608775846
#
# 1 3.223294762206946
# 2 3.3028497590939963
# 3 3.3095110082891934
# 4 3.309665480578404
# 5 3.310457448023776
# 6 3.3109053490947082
# Convergence reached at 6 components
# Total time to run the procedure: 95.07 s
#
# 3 26 0.04762377327578119 0.010908364436133014
#
# 1 3.3782960211962774
# 2 3.463592912725518
# 3 3.4773295016598644
# 4 3.4822510644557156
# 5 3.4823961258579677
# Convergence reached at 5 components
# Total time to run the procedure: 67.46 s
#
# 3 27 0.030810589451604593 0.0076884225427390745
#
# 1 3.4661090179214082
# 2 3.689406823196501
# 3 3.7124523734663377
# 4 3.7166079893619623
# Convergence reached at 4 components
# Total time to run the procedure: 37.30 s
#
# 3 28 0.029630611213150894 0.006440367680429635
#
# 1 3.7592734426501018
# 2 3.8324249321029753
# 3 3.8545310832941673
# Convergence reached at 3 components
# Total time to run the procedure: 26.46 s
#
# 3 29 0.013974287835077459 0.0042228480346739195
#
# 1 3.218436108900557
# 2 3.31937671647141
# 3 3.331609624722707
# 4 3.3318430211783436
# Convergence reached at 4 components
# Total time to run the procedure: 41.64 s
#
# 3 30 0.03179304379504796 0.005695011176957916
#
# 1 3.611993166105893
# 2 3.692460679466926
# Convergence reached at 2 components
# Total time to run the procedure: 17.51 s
#
# 3 31 0.05114854012389552 0.008125190270396886
#
# 1 3.607779325507759
# 2 3.6904060880023923
# 3 3.693376092165306
# 4 3.695162726929452
# Convergence reached at 4 components
# Total time to run the procedure: 50.10 s
#
# 3 32 0.0310016998778734 0.007318783740734935
#
# 1 3.2163880001785685
# 2 3.392458469829679
# 3 3.4120978495066354
# Convergence reached at 3 components
# Total time to run the procedure: 22.23 s
#
# 3 33 0.025466366728454752 0.005931548035047599
#
# 1 3.548980630499089
# 2 3.6295276522286772
# 3 3.6386586584278553
# 4 3.644563820106331
# Convergence reached at 4 components
# Total time to run the procedure: 50.86 s
#
# 3 34 0.04220040228258861 0.0061518070777357315
#
# 1 3.7196315644005833
# 2 3.82616795945477
# 3 3.832176575198489
# Convergence reached at 3 components
# Total time to run the procedure: 37.82 s
#
# 3 35 0.017617792687189052 0.006708001019265438
#
# 1 3.384604740486051
# 2 3.4692652636387886
# 3 3.5042490828746833
# 4 3.526890541853886
# Convergence reached at 4 components
# Total time to run the procedure: 38.79 s
#
# 3 36 0.05831383064194281 0.01037333255075818
#
# 1 3.8244046577976363
# 2 3.917411445909709
# 3 3.9430241991696366
# Convergence reached at 3 components
# Total time to run the procedure: 29.55 s
#
# 3 37 0.023901525391754448 0.0069241422627256645
#
# 1 3.510101190548601
# 2 3.624811274314068
# 3 3.6332362285404898
# 4 3.6356784816071523
# 5 3.6381691612112284
# 6 3.6405275900798295
# Convergence reached at 6 components
# Total time to run the procedure: 87.01 s
#
# 3 38 0.047103181856316 0.007858948707803563
#
# 1 3.454775392891254
# 2 3.5383386273521933
# 3 3.550527939415264
# 4 3.5531065797885497
# 5 3.5540397547325946
# 6 3.5578690344693746
# Convergence reached at 6 components
# Total time to run the procedure: 111.19 s
#
# 3 39 0.034930470496078114 0.010025850047907544
#
# 1 3.537603830578363
# 2 3.6240577333532205
# 3 3.6268181298835214
# 4 3.6283225092835742
# 5 3.628663897466043
# Convergence reached at 5 components
# Total time to run the procedure: 80.38 s
#
# 3 40 0.023794297958115135 0.006513122152940387
#
# 1 3.7363197270582376
# 2 3.8333032046047593
# 3 3.8477562357387485
# 4 3.8503560868927096
# 5 3.8531908919604074
# 6 3.8541164197417124
# Convergence reached at 6 components
# Total time to run the procedure: 88.68 s
#
# 3 41 0.06488987186595047 0.009715994109163328
#
# 1 3.573947025010168
# 2 3.6608122986254714
# 3 3.7204701563206197
# 4 3.7225549668302365
# 5 3.725611915179389
# Convergence reached at 5 components
# Total time to run the procedure: 62.55 s
#
# 3 42 0.026853044604129944 0.006105038397584726
#
# 1 3.3515829929330816
# 2 3.4331558024878626
# 3 3.4384792199766068
# 4 3.439982352378566
# Convergence reached at 4 components
# Total time to run the procedure: 47.45 s
#
# 3 43 0.017620545421313284 0.005589021558555204
#
# 1 3.5896339761746483
# 2 3.6738888093324342
# 3 3.696624331366769
# 4 3.698853180658258
# 5 3.7037606184429155
# 6 3.711351037379158
# Convergence reached at 6 components
# Total time to run the procedure: 101.41 s
#
# 3 44 0.023501890225034044 0.0073319750850593364
#
# 1 3.6636573783631525
# 2 3.7599932555964934
# 3 3.7974880046426116
# Convergence reached at 3 components
# Total time to run the procedure: 29.52 s
#
# 3 45 0.009416405720027115 0.003253326447579329
#
# 1 3.346552801492877
# 2 3.436838464582653
# 3 3.445367992064877
# 4 3.4488686906582404
# 5 3.453034279614526
# Convergence reached at 5 components
# Total time to run the procedure: 63.59 s
#
# 3 46 0.06471858729773844 0.009370596195184905
#
# 1 3.040011210517569
# 2 3.131401148950578
# 3 3.1623737059558095
# 4 3.1730408715169864
# Convergence reached at 4 components
# Total time to run the procedure: 38.07 s
#
# 3 47 0.03831237737422094 0.006784283645977691
#
# 1 3.4614110812710557
# 2 3.5587483359228553
# 3 3.5693999498875644
# 4 3.5776498680268296
# Convergence reached at 4 components
# Total time to run the procedure: 42.88 s
#
# 3 48 0.02073299245121192 0.005621204142318587
#
# 1 3.414174689285882
# 2 3.4950237161339373
# 3 3.4970364295351746
# 4 3.498837512058073
# Convergence reached at 4 components
# Total time to run the procedure: 52.47 s
#
# 3 49 0.013922747230595594 0.0057055300277753995
#
# 1 3.399098997319301
# 2 3.5276073115484308
# 3 3.5415813776576752
# 4 3.5430655507055455
# 5 3.546865808115814
# 6 3.548357395257014
# 7 3.5495290367910006
# Convergence reached at 7 components
# Total time to run the procedure: 136.76 s
#
# 3 50 0.08522898444200971 0.013144949001560088
#
# 1 3.6594964297126182
# 2 3.749718345539464
# 3 3.755368673539364
# 4 3.7627659027705973
# 5 3.7634646713868496
# Convergence reached at 5 components
# Total time to run the procedure: 78.57 s
#
# 3 51 0.04133795354373504 0.007545727711160979
#
# 1 3.211229209178878
# 2 3.294707854846591
# 3 3.297119919272476
# 4 3.2975325509494655
# Convergence reached at 4 components
# Total time to run the procedure: 59.00 s
#
# 3 52 0.029744983812562503 0.007820857903804566
#
# 1 3.3773197715757317
# 2 3.4553440019851878
# 3 3.507303551164018
# 4 3.517575158911017
# 5 3.517616601659581
# Convergence reached at 5 components
# Total time to run the procedure: 65.02 s
#
# 3 53 0.024490964110440085 0.005687990886623863
#
# 1 3.4735804454642927
# 2 3.559481333412015
# 3 3.5614345842991564
# Convergence reached at 3 components
# Total time to run the procedure: 34.84 s
#
# 3 54 0.021079011823634274 0.007608257386503092
#
# 1 3.2109844036981325
# 2 3.353917438228278
# 3 3.38231734296815
# 4 3.3911940323414846
# Convergence reached at 4 components
# Total time to run the procedure: 32.32 s
#
# 3 55 0.052292670103819286 0.007174748427783147
#
# 1 3.0263446590989815
# 2 3.109773150643914
# 3 3.1308200431995687
# 4 3.1342483184981247
# Convergence reached at 4 components
# Total time to run the procedure: 48.30 s
#
# 3 56 0.0184051695866522 0.005908392533035452
#
# 1 3.2705964405537435
# 2 3.3397483129985734
# 3 3.3649321680360162
# 4 3.377095351061436
# Convergence reached at 4 components
# Total time to run the procedure: 47.46 s
#
# 3 57 0.011356486386496514 0.006247687252539463
#
# 1 0.3689840900266265
# 2 1.2934874750511802
# 3 1.3905574052934007
# 4 1.410304307833652
# Convergence reached at 4 components
# Total time to run the procedure: 34.48 s
#
# 3 58 0.0371937015280993 0.009220020824210978
#
# 1 3.156770943427155
# 2 3.2416510119455686
# 3 3.2626971068699846
# Convergence reached at 3 components
# Total time to run the procedure: 27.20 s
#
# 3 59 0.01062090161912304 0.0037562986782353454
#
# 1 3.2303027092010375
# 2 3.319075953984473
# 3 3.3558746363741263
# Convergence reached at 3 components
# Total time to run the procedure: 22.06 s
#
# 3 60 0.03247563546524741 0.005518368401565812
#
# 1 3.6663889296750525
# 2 3.744245855592665
# 3 3.7485397857832
# Convergence reached at 3 components
# Total time to run the procedure: 41.96 s
#
# 3 61 0.04217970680677054 0.007955357125676769
#
# 1 3.5647713040801556
# 2 3.6485729998060297
# 3 3.6511097642973134
# 4 3.6573474875250134
# Convergence reached at 4 components
# Total time to run the procedure: 52.06 s
#
# 3 62 0.059223465739882686 0.00800272552125369
#
# 1 3.2829371237272493
# 2 3.4609756018139612
# 3 3.48783252130452
# Convergence reached at 3 components
# Total time to run the procedure: 22.36 s
#
# 3 63 0.0649665185304891 0.00965375267565511
#
# 1 3.847441943876671
# 2 3.9292571561711216
# 3 3.9533391574079997
# 4 3.9545009378454394
# Convergence reached at 4 components
# Total time to run the procedure: 41.92 s
#
# 3 64 0.01749927589183315 0.004463846524607407
#
# 1 3.246744487417478
# 2 3.366025049248311
# 3 3.378744549002924
# 4 3.3856891783425898
# 5 3.397085432979964
# Convergence reached at 5 components
# Total time to run the procedure: 61.54 s
#
# 3 65 0.03689976371661868 0.007605819588973533
#
# 1 3.3819894998140945
# 2 3.462268781517627
# 3 3.485389803740727
# 4 3.4875063854529595
# 5 3.4926912204128606
# Convergence reached at 5 components
# Total time to run the procedure: 66.43 s
#
# 3 66 0.07499656617392012 0.009081961155039363
#
# 1 3.2694517913404364
# 2 3.363963556118519
# 3 3.4020158434165864
# 4 3.4031544316106266
# Convergence reached at 4 components
# Total time to run the procedure: 36.41 s
#
# 3 67 0.015613219316600207 0.00529984827446974
#
# 1 3.361345566760976
# 2 3.4543106911780854
# 3 3.461047973585606
# 4 3.4659647965394935
# 5 3.466349484920243
# 6 3.468434240924612
# Convergence reached at 6 components
# Total time to run the procedure: 93.21 s
#
# 3 68 0.049976261215040944 0.00965196981171084
#
# 1 3.6528898509884855
# 2 3.7721480159149947
# 3 3.79292078677832
# Convergence reached at 3 components
# Total time to run the procedure: 28.40 s
#
# 3 69 0.02132059902952171 0.004997576563573398
#
# 1 3.3868528743448167
# 2 3.468133677160677
# 3 3.470931048225451
# 4 3.471592933702979
# 5 3.4716654712810873
# Convergence reached at 5 components
# Total time to run the procedure: 61.45 s
#
# 3 70 0.03487093872236307 0.006175303818153496
#
# 1 3.3187036409533217
# 2 3.398443086048584
# 3 3.4094257155756194
# Convergence reached at 3 components
# Total time to run the procedure: 26.58 s
#
# 3 71 0.013820237087329384 0.005237163224460349
#
# 1 3.715052798757094
# 2 3.8122345841146967
# 3 3.826192623913787
# 4 3.829544808541091
# Convergence reached at 4 components
# Total time to run the procedure: 41.98 s
#
# 3 72 0.04286022124231679 0.006901250797325443
#
# 1 3.3429042677698764
# 2 3.4590220757990866
# 3 3.477659735682664
# 4 3.4863147548952536
# 5 3.487615171604878
# Convergence reached at 5 components
# Total time to run the procedure: 57.16 s
#
# 3 73 0.01894551760642583 0.004804157779183456
#
# 1 3.7747694147033717
# 2 3.9064198526594596
# 3 3.935090994714472
# 4 3.94715208310536
# Convergence reached at 4 components
# Total time to run the procedure: 43.14 s
#
# 3 74 0.017956098135849006 0.00528792219177798
#
# 1 3.373188147128967
# 2 3.452313283296128
# 3 3.459902443482172
# 4 3.4655373327487218
# 5 3.469112000584308
# 6 3.4734550107103446
# 7 3.473915613095297
# Convergence reached at 7 components
# Total time to run the procedure: 135.99 s
#
# 3 75 0.03089485501362228 0.01046721490028802
#
# 1 3.2915700877383345
# 2 3.3684272534196267
# 3 3.3915462758385373
# 4 3.392973713981552
# Convergence reached at 4 components
# Total time to run the procedure: 40.15 s
#
# 3 76 0.012449528130236469 0.004201238810367196
#
# 1 3.576840245832083
# 2 3.67913295675865
# 3 3.7114687246421947
# 4 3.7309344603819192
# Convergence reached at 4 components
# Total time to run the procedure: 41.28 s
#
# 3 77 0.018315997235600262 0.006067354069354799
#
# 1 3.3680111037478166
# 2 3.451175959988371
# Convergence reached at 2 components
# Total time to run the procedure: 19.61 s
#
# 3 78 0.00409525242142051 0.0020993557501742793
#
# 1 3.6508188873896947
# 2 3.72477528773895
# 3 3.756550224287994
# Convergence reached at 3 components
# Total time to run the procedure: 32.04 s
#
# 3 79 0.0959285824634875 0.011040596017334061
#
# 1 3.8077091381507437
# 2 3.890152956962923
# 3 3.898272973452508
# 4 3.902449036586935
# Convergence reached at 4 components
# Total time to run the procedure: 48.08 s
#
# 3 80 0.01141237609959973 0.0038027158598865863
#
# 1 3.7690384262023415
# 2 3.852374899694818
# 3 3.8624977663545326
# Convergence reached at 3 components
# Total time to run the procedure: 24.67 s
#
# 3 81 0.009227101967514985 0.003432920937710106
#
# 1 3.394810687582563
# 2 3.4747224849547886
# 3 3.4762414403922577
# Convergence reached at 3 components
# Total time to run the procedure: 33.07 s
#
# 3 82 0.026140221451376656 0.005187681644259152
#
# 1 3.423862095428514
# 2 3.499987342281097
# 3 3.5316931713787962
# 4 3.538255107087643
# 5 3.551300350343784
# Convergence reached at 5 components
# Total time to run the procedure: 68.09 s
#
# 3 83 0.01756738415045934 0.005863905726933592
#
# 1 3.557566446120108
# 2 3.671271912327336
# 3 3.724278385664876
# 4 3.7329988847051125
# Convergence reached at 4 components
# Total time to run the procedure: 39.75 s
#
# 3 84 0.02107569098646725 0.0046392553503549405
#
# 1 -0.9114431167151046
# 2 -0.8305714018420813
# 3 -0.8160843167533613
# 4 -0.8136627687998818
# Convergence reached at 4 components
# Total time to run the procedure: 48.96 s
#
# 3 85 0.028439305103658517 0.006430493872366537
#
# 1 3.3121412661267176
# 2 3.3964337740215282
# 3 3.418200923727827
# Convergence reached at 3 components
# Total time to run the procedure: 27.62 s
#
# 3 86 0.04812733390373377 0.006846850485574807
#
# 1 3.5114000166837402
# 2 3.589865280659924
# 3 3.593496019508782
# Convergence reached at 3 components
# Total time to run the procedure: 41.45 s
#
# 3 87 0.07879991899795696 0.009746360139693395
#
# 1 3.532148767885838
# 2 3.6692434891246357
# 3 3.717201053686548
# 4 3.734629562400508
# 5 3.737246280526872
# 6 3.738154012932575
# Convergence reached at 6 components
# Total time to run the procedure: 80.03 s
#
# 3 88 0.02290933357545574 0.006078014647205985
#
# 1 3.3847330692752293
# 2 3.4906229056375317
# 3 3.4981248343717115
# 4 3.5030479767557936
# Convergence reached at 4 components
# Total time to run the procedure: 43.15 s
#
# 3 89 0.02776288351770292 0.0064145186730860775
#
# 1 4.026406793174229
# 2 4.110993438617984
# 3 4.126288983299369
# 4 4.127789259015099
# Convergence reached at 4 components
# Total time to run the procedure: 47.63 s
#
# 3 90 0.053921740248732176 0.008427947745217435
#
# 1 3.365985794688734
# 2 3.4567631192796067
# 3 3.458108888972958
# Convergence reached at 3 components
# Total time to run the procedure: 32.54 s
#
# 3 91 0.015711417499014994 0.005349910316642037
#
# 1 3.4109570613819735
# 2 3.4947201489686646
# 3 3.508269594225439
# 4 3.5213951194284605
# 5 3.5270777631617807
# Convergence reached at 5 components
# Total time to run the procedure: 69.41 s
#
# 3 92 0.025855824122995075 0.007870754150345502
#
# 1 3.6156887980557966
# 2 3.7255748086207965
# 3 3.7737795545436748
# 4 3.774708577956439
# 5 3.7760626729773428
# 6 3.7799585324113134
# Convergence reached at 6 components
# Total time to run the procedure: 100.71 s
#
# 3 93 0.017799606010972826 0.00685442781247718
#
# 1 3.173981392364285
# 2 3.2755475529835394
# 3 3.2934052393842848
# 4 3.2965779490790674
# Convergence reached at 4 components
# Total time to run the procedure: 42.58 s
#
# 3 94 0.038090455536692366 0.007939044971167541
#
# 1 3.392596685840578
# 2 3.495334124164826
# 3 3.5203359041932374
# 4 3.528114797740894
# Convergence reached at 4 components
# Total time to run the procedure: 47.40 s
#
# 3 95 0.032223986427717025 0.005312751639862038
#
# 1 3.5572949742389697
# 2 3.652515562942457
# 3 3.6913236198282036
# 4 3.6954514344487706
# Convergence reached at 4 components
# Total time to run the procedure: 44.74 s
#
# 3 96 0.05286500237010875 0.011235094075420829
#
# 1 3.2694797916549034
# 2 3.3517109378154633
# Convergence reached at 2 components
# Total time to run the procedure: 18.52 s
#
# 3 97 0.012607370279139597 0.0032743169808472404
#
# 1 3.2971709117431716
# 2 3.37026324158397
# 3 3.380995251015159
# 4 3.382372762381163
# 5 3.3830819861061183
# Convergence reached at 5 components
# Total time to run the procedure: 70.54 s
#
# 3 98 0.021977889724846635 0.007304579882990793
#
# 1 -1.5116822883856988
# 2 -1.4316207849577587
# 3 -1.3927094688733088
# 4 -1.3744759418389967
# 5 -1.3492391917823785
# 6 -1.3473553656566566
# 7 -1.325618605436872
# 8 -1.3211803792653178
# Convergence reached at 8 components
# Total time to run the procedure: 165.40 s
#
# 3 99 0.0497530834268086 0.014371090219004796
#
# 1 3.7562496576176616
# 2 3.8620095642798176
# 3 3.8864719342629264
# 4 3.898896605874738
# 5 3.902468623111026
# Convergence reached at 5 components
# Total time to run the procedure: 62.69 s
#
# 3 100 0.01968627324629471 0.00530414825744339
#
# 1 3.370432031281306
# 2 3.4547592129155866
# 3 3.475653698829713
# 4 3.491316406832123
# Convergence reached at 4 components
# Total time to run the procedure: 40.99 s
#
# 3 101 0.02077994088978466 0.005168148052588806
#
# 1 3.300787895633744
# 2 3.403192109429948
# 3 3.4214459672227058
# Convergence reached at 3 components
# Total time to run the procedure: 21.43 s
#
# 3 102 0.04487209826785258 0.007222176231836913
#
# 1 3.2216881688036207
# 2 3.3046203759845896
# 3 3.317507520187007
# Convergence reached at 3 components
# Total time to run the procedure: 42.32 s
#
# 3 103 0.01573641089571214 0.005605319195895813
#
# 1 3.4756734073089794
# 2 3.556339289910566
# 3 3.5977449702610844
# 4 3.600610860976895
# Convergence reached at 4 components
# Total time to run the procedure: 44.05 s
#
# 3 104 0.01697840572750065 0.006893021970545093
#
# 1 3.5622631811874705
# 2 3.647756046076445
# 3 3.657657564060537
# 4 3.6597978484078943
# 5 3.6627118113044825
# Convergence reached at 5 components
# Total time to run the procedure: 71.34 s
#
# 3 105 0.02843814445742848 0.00634237678383834
#
# 1 3.230158981138777
# 2 3.3315730944705906
# 3 3.333909869727561
# Convergence reached at 3 components
# Total time to run the procedure: 27.08 s
#
# 3 106 0.015253832093892576 0.003391740996297819
#
# 1 3.2925656486005983
# 2 3.3898083905161442
# 3 3.41922941324882
# Convergence reached at 3 components
# Total time to run the procedure: 30.79 s
#
# 3 107 0.015361456758196453 0.005487411806418339
#
# 1 3.284749314212353
# 2 3.3593299519359765
# 3 3.3682623276611543
# 4 3.369164986921961
# 5 3.371458455849013
# Convergence reached at 5 components
# Total time to run the procedure: 77.51 s
#
# 3 108 0.04671511030168376 0.009959238327682064
#
# 1 3.4716753461902905
# 2 3.5529361184670076
# 3 3.559791191940837
# Convergence reached at 3 components
# Total time to run the procedure: 33.90 s
#
# 3 109 0.027473898872343888 0.0060633551729675885
#
# 1 3.1492695994107667
# 2 3.2299282814916217
# 3 3.2333480843346414
# 4 3.2343804640304654
# Convergence reached at 4 components
# Total time to run the procedure: 46.76 s
#
# 3 110 0.031636712682932715 0.006214096887338244
#
# 1 3.3724645311303263
# 2 3.4670060946276404
# 3 3.486082329853115
# 4 3.4943100715783495
# 5 3.4957492307172173
# 6 3.4960534184448697
# 7 3.4962422301420766
# Convergence reached at 7 components
# Total time to run the procedure: 137.27 s
#
# 3 111 0.03162012977809945 0.009345970395605271
#
# 1 3.4606850582051405
# 2 3.5550851475630707
# 3 3.609302055714774
# Convergence reached at 3 components
# Total time to run the procedure: 32.05 s
#
# 3 112 0.03970666529826454 0.0069890481363823875
#
# 1 3.2626563619409414
# 2 3.3760187005437996
# 3 3.4025001054501716
# Convergence reached at 3 components
# Total time to run the procedure: 27.97 s
#
# 3 113 0.021642898754407898 0.005371151435995324
#
# 1 3.321354642672086
# 2 3.4172419892525556
# 3 3.4535079853789994
# 4 3.4588211158652875
# Convergence reached at 4 components
# Total time to run the procedure: 44.85 s
#
# 3 114 0.03343567014214857 0.006326205776814499
#
# 1 3.5798013790283174
# 2 3.722041775332038
# 3 3.8373517067898795
# 4 3.8466372057602416
# 5 3.8485023389149724
# 6 3.850692542099651
# Convergence reached at 6 components
# Total time to run the procedure: 90.58 s
#
# 3 115 0.04290273727598112 0.008104405005784755
#
# 1 3.671723681134639
# 2 3.7677234418898533
# Convergence reached at 2 components
# Total time to run the procedure: 17.14 s
#
# 3 116 0.031235654170382893 0.005767157513520528
#
# 1 3.1778930763680955
# 2 3.265043687421159
# 3 3.2782930637369216
# Convergence reached at 3 components
# Total time to run the procedure: 24.87 s
#
# 3 117 0.015966922236850572 0.006231106954873666
#
# 1 3.2096496656799087
# 2 3.3718934365588367
# 3 3.4001717998848418
# 4 3.4078403270145596
# Convergence reached at 4 components
# Total time to run the procedure: 37.81 s
#
# 3 118 0.04316709608244369 0.00678121680820008
#
# 1 3.150398285023266
# 2 3.248630385651348
# 3 3.2585647624227216
# 4 3.2655913763083153
# Convergence reached at 4 components
# Total time to run the procedure: 49.20 s
#
# 3 119 0.0255757680475867 0.007268350228890182
#
# 1 3.540611465239262
# 2 3.62942998505701
# 3 3.665981384568333
# 4 3.6691583137565953
# 5 3.6719504243112797
# Convergence reached at 5 components
# Total time to run the procedure: 62.53 s
#
# 3 120 0.0492386675310589 0.008491161933094475
#
# 1 3.6142690327487266
# 2 3.6955041072759776
# 3 3.716515455192546
# 4 3.7185823181991022
# Convergence reached at 4 components
# Total time to run the procedure: 59.28 s
#
# 3 121 0.018431873010216523 0.004756355155967402
#
# 1 3.4354749047047464
# 2 3.5601106809105807
# 3 3.5797843611930085
# Convergence reached at 3 components
# Total time to run the procedure: 21.40 s
#
# 3 122 0.00941098505922242 0.0035763746883975744
#
# 1 3.4225962654439996
# 2 3.5118098615262032
# 3 3.5300722185032023
# 4 3.5333091116983897
# Convergence reached at 4 components
# Total time to run the procedure: 45.03 s
#
# 3 123 0.04345271175172306 0.006374520516594516
#
# 1 -1.5649895841923922
# 2 -1.4827302536966966
# 3 -1.4824253141336732
# 4 -1.4788448532077043
# 5 -1.476626632816247
# 6 -1.474410204212828
# Convergence reached at 6 components
# Total time to run the procedure: 141.51 s
#
# 3 124 0.02814582019609294 0.009335072988120429
#
# 1 3.8107163296954205
# 2 3.91617787943625
# 3 3.9410055222778397
# Convergence reached at 3 components
# Total time to run the procedure: 33.31 s
#
# 3 125 0.015331502364246725 0.00908967164531878
#
# 1 3.2678631159464318
# 2 3.3756884766916273
# 3 3.414622012674739
# Convergence reached at 3 components
# Total time to run the procedure: 20.11 s
#
# 3 126 0.021458689693123402 0.004168045179780647
#
# 1 3.4681726624909905
# 2 3.5524116318735905
# 3 3.569703926029573
# Convergence reached at 3 components
# Total time to run the procedure: 34.19 s
#
# 3 127 0.02530389023798547 0.004458695159281718
#
# 1 2.588404234970073
# 2 2.880929380647626
# 3 2.962568012516187
# 4 3.4214945988957606
# 5 3.46496627543517
# 6 3.6914690697502084
# 7 3.7000867715465717
# 8 3.708835538360045
# 9 3.7147284655799235
# 10 3.71907341225447
# 11 3.721471597843266
# 12 3.7226081706158802
# Convergence reached at 12 components
# Total time to run the procedure: 523.11 s
#
# 4 0 0.03951027426427076 0.002980021020932518
#
# 1 2.4489479544845323
# 2 3.4970536417253033
# 3 3.841561877298193
# 4 3.8830276030212976
# 5 3.900876490683212
# 6 3.911626885982969
# 7 3.9188767523125794
# 8 3.9217348734535484
# 9 3.922261047041872
# 10 3.928291676569941
# Convergence reached at 10 components
# Total time to run the procedure: 389.15 s
#
# 4 1 0.021900394973797362 0.006519888811310948
#
# 1 3.330139104455498
# 2 3.4382790705554753
# 3 3.4864361445535414
# 4 3.5145896179553673
# 5 3.5233850152998065
# 6 3.531339322422866
# 7 3.534557845094097
# 8 3.7147351509731004
# 9 3.888733104672751
# Convergence reached at 9 components
# Total time to run the procedure: 470.75 s
#
# 4 2 0.016369445583207565 0.008689336838794453
#
# 1 3.3828633661319336
# 2 3.48765918329682
# 3 3.5279954956658632
# 4 3.551237384009396
# 5 3.8438491367437
# 6 3.8449407021868964
# 7 3.8569371777443915
# 8 4.010806115096096
# 9 4.013630131705273
# 10 4.014536042020346
# 11 4.015110066468883
# 12 4.016453938215785
# Convergence reached at 12 components
# Total time to run the procedure: 547.90 s
#
# 4 3 0.028337192562030437 0.002292571438719556
#
# 1 3.491787902830166
# 2 3.62858001746176
# 3 3.701592321981139
# 4 3.7370138279371807
# 5 3.7495331625939694
# 6 3.7630241001818967
# 7 3.7686380940962643
# 8 3.912987315918117
# 9 3.923712754273969
# 10 4.204011168626129
# 11 4.205607971321268
# Convergence reached at 11 components
# Total time to run the procedure: 597.16 s
#
# 4 4 0.027081763440170544 0.007928549513451672
#
# 1 2.6518468695491997
# 2 2.8379741436399706
# 3 2.895759379140319
# 4 2.931751783927423
# 5 3.6389263670270204
# 6 3.644971701514974
# 7 3.653086000040712
# 8 3.6625553754885174
# 9 3.665110602615353
# 10 3.665382323873582
# 11 3.66731850717783
# 12 3.669280620070545
# Convergence reached at 12 components
# Total time to run the procedure: 541.76 s
#
# 4 5 0.030897600722896983 0.0029702232865026178
#
# 1 3.292255933637699
# 2 3.4027765446674167
# 3 3.4498761223694423
# 4 3.4808969368291844
# 5 3.4901495112544842
# 6 3.6254409340822185
# 7 3.6328923800318624
# 8 3.9122044929475446
# 9 3.9148999061721628
# Convergence reached at 9 components
# Total time to run the procedure: 385.10 s
#
# 4 6 0.02346982611680887 0.007692129750832385
#
# 1 2.493101366176371
# 2 2.67348702843138
# 3 2.74652353840829
# 4 2.7810074895302836
# 5 3.4780793760439237
# 6 3.4796782041539913
# 7 3.4947906492872938
# 8 3.503742160188897
# 9 3.506538570823474
# 10 3.5135116581340653
# Convergence reached at 10 components
# Total time to run the procedure: 416.30 s
#
# 4 7 0.03223412721181754 0.003655686476603985
#
# 1 2.6930655486375215
# 2 3.3487201776467743
# 3 3.91659736334848
# 4 3.9646461458212534
# 5 3.978392829230773
# 6 3.990041839644538
# 7 3.9968763103621825
# 8 3.998498714738009
# 9 4.000566894177837
# 10 4.005214160427967
# Convergence reached at 10 components
# Total time to run the procedure: 367.48 s
#
# 4 8 0.027833445344632564 0.006410245879251673
#
# 1 2.5542429748851707
# 2 2.6630737549291585
# 3 2.719185634935233
# 4 2.7570732847901773
# 5 2.98277389332488
# 6 3.2091261286140127
# 7 3.4607208187854237
# 8 3.4688130376044293
# 9 3.478913902529109
# 10 3.4819623875842733
# 11 3.4820576726832217
# Convergence reached at 11 components
# Total time to run the procedure: 555.03 s
#
# 4 9 0.03341979733187162 0.003666626695936749
#
# 1 2.3982388839011315
# 2 2.896951297855948
# 3 3.7004617801027426
# 4 3.7420324562609597
# 5 3.7609485773878313
# 6 3.7724086958220364
# 7 3.7740487443125144
# 8 3.778011114777534
# 9 3.7801970208080817
# 10 3.7844890502904907
# Convergence reached at 10 components
# Total time to run the procedure: 387.50 s
#
# 4 10 0.032471192690065924 0.0063463873832954746
#
# 1 -1.6781371152603886
# 2 -1.564149828137278
# 3 -1.5157918116605502
# 4 -1.485359732891163
# 5 -0.46892897417291385
# Convergence reached at 5 components
# Total time to run the procedure: 131.12 s
#
# 4 11 0.024502545606457447 0.004616298562756446
#
# 1 2.428081014753843
# 2 2.9169697369531318
# 3 3.014135419245674
# 4 3.053920672970412
# 5 3.545488178938971
# 6 3.5539370051514534
# 7 3.5671061122136956
# 8 3.573129017912256
# 9 3.5743246698266558
# 10 3.5750896987895806
# 11 3.5760215400492936
# Convergence reached at 11 components
# Total time to run the procedure: 536.75 s
#
# 4 12 0.04869761468204291 0.003945440904425343
#
# 1 2.9836665415954378
# 2 3.095612092514157
# 3 3.137037518627078
# 4 3.150741672819605
# 5 3.1647272081154036
# 6 3.1673186100478503
# 7 3.1699053561870376
# 8 3.1707036638140913
# 9 3.3358904196990493
# 10 3.49917771845913
# 11 3.646040690106705
# 12 3.6462773006786553
# Convergence reached at 12 components
# Total time to run the procedure: 787.75 s
#
# 4 13 0.02985769722950282 0.01048375095984565
#
# 1 3.0327988373634387
# 2 3.1378217443318044
# 3 3.181376204906736
# 4 3.2056550863275963
# 5 3.2153542966779565
# 6 3.217823614316854
# 7 3.227055019083663
# 8 3.231155769610846
# 9 3.377241187721847
# 10 3.5471721074271905
# 11 3.702377152217297
# 12 3.704248308096403
# 13 3.7070991293187086
# Convergence reached at 13 components
# Total time to run the procedure: 797.39 s
#
# 4 14 0.041516543138188304 0.006870301285677907
#
# 1 2.3835118143074507
# 2 3.1094527005172474
# 3 3.2041139258033886
# 4 3.246368863810471
# 5 3.286847819831775
# 6 3.7950329545824744
# 7 3.8077444085909584
# 8 3.8117025970858993
# 9 3.812385485401874
# Convergence reached at 9 components
# Total time to run the procedure: 438.46 s
#
# 4 15 0.025218784864965094 0.002832765029223477
#
# 1 2.5056429356462293
# 2 2.7313702413543512
# 3 2.80304801483398
# 4 3.063208543560346
# 5 3.5525399144488112
# 6 3.560864966203521
# 7 3.5750125527740546
# 8 3.582042884092742
# 9 3.5842609083237984
# 10 3.586601501384873
# 11 3.587510152656504
# 12 3.5888581780343896
# Convergence reached at 12 components
# Total time to run the procedure: 562.20 s
#
# 4 16 0.03659385153253329 0.002858979820015398
#
# 1 2.9441292078509083
# 2 3.172448620503598
# 3 3.246668848426999
# 4 3.486907629199012
# 5 3.9676585369893735
# 6 3.9827575540130593
# 7 3.991751314159302
# 8 3.999860703526311
# 9 4.004491217575803
# 10 4.006940563971812
# Convergence reached at 10 components
# Total time to run the procedure: 437.07 s
#
# 4 17 0.03134187156185954 0.003955177302663419
#
# 1 2.999658665897201
# 2 3.1914420358324587
# 3 3.260839631287626
# 4 3.30436331257293
# 5 3.9565405697011156
# Convergence reached at 5 components
# Total time to run the procedure: 94.16 s
#
# 4 18 0.034870890098089496 0.005746558576789755
#
# 1 -1.0248311942394384
# 2 -0.6278272187057796
# 3 -0.5563207733638825
# 4 -0.5211016979950074
# 5 -0.27578637222761987
# 6 -0.25328481315118295
# 7 -0.03319754194335947
# 8 0.17291213332919853
# Convergence reached at 8 components
# Total time to run the procedure: 244.02 s
#
# 4 19 0.04150151635980535 0.0040680685494285
#
# 1 2.5527669313597188
# 2 2.905311136755835
# 3 2.983348102562294
# 4 3.0146883389896275
# 5 3.265815042089596
# 6 3.2817570046726487
# 7 3.764791094818868
# 8 3.7676108388990137
# 9 3.7750152791272114
# 10 3.777381737738658
# Convergence reached at 10 components
# Total time to run the procedure: 408.34 s
#
# 4 20 0.03445674851379781 0.0033020743855655807
#
# 1 2.3265487315799223
# 2 2.916235744267509
# 3 3.0055404143794795
# 4 3.5280303462007008
# Convergence reached at 4 components
# Total time to run the procedure: 78.48 s
#
# 4 21 0.022508995910426263 0.004602694152342591
#
# 1 2.5230072438118545
# 2 3.1307698821286927
# 3 3.224836853388148
# 4 3.273828777262112
# 5 3.7859064564788425
# 6 3.7980409104675323
# 7 3.808747766577209
# 8 3.8095388580935197
# 9 3.810344187383588
# Convergence reached at 9 components
# Total time to run the procedure: 405.34 s
#
# 4 22 0.025683149694273703 0.002900729433215546
#
# 1 3.081009570038692
# 2 3.188333385837454
# 3 3.232609795477972
# 4 3.261470816666062
# 5 3.2725980600687605
# 6 3.2852714454048795
# 7 3.2864347121977713
# 8 3.811684458947664
# 9 3.8132076392706344
# Convergence reached at 9 components
# Total time to run the procedure: 511.65 s
#
# 4 23 0.02745180596009931 0.006000770499223596
#
# 1 2.512711860149444
# 2 2.7885498750704385
# 3 2.8578475961085004
# 4 3.104747521137792
# 5 3.5773053638464103
# 6 3.601119760371013
# Convergence reached at 6 components
# Total time to run the procedure: 110.74 s
#
# 4 24 0.02790071632137735 0.0037892180233634752
#
# 1 2.523236511512804
# 2 2.8531103500427335
# 3 2.931611719708736
# 4 3.452542891075005
# 5 3.7001175968946605
# 6 3.709486983138467
# 7 3.7199284959937464
# 8 3.730848198258552
# 9 3.7334395424951903
# 10 3.7367325453652818
# 11 3.7369356605662603
# 12 3.73736676083122
# 13 3.738476610069134
# Convergence reached at 13 components
# Total time to run the procedure: 706.65 s
#
# 4 25 0.03132916872375868 0.0028080490517397214
#
# 1 2.812243178263961
# 2 2.916509312752827
# 3 2.9576412113287254
# 4 2.9819030270085185
# 5 2.996269813182499
# 6 3.0024569751619405
# 7 3.0061486373637596
# 8 3.0085841169143195
# Convergence reached at 8 components
# Total time to run the procedure: 390.81 s
#
# 4 26 0.008594605225912452 0.0015541368609479113
#
# 1 2.823702080107511
# 2 2.933582836198875
# 3 2.9810099587137615
# 4 3.0030961620368832
# 5 3.023906714733928
# 6 3.4391882827340434
# 7 3.6378952279039063
# 8 3.642379565616512
# 9 3.644354804140912
# 10 3.6458325173620802
# 11 3.6468539255633057
# 12 3.6495673887338236
# Convergence reached at 12 components
# Total time to run the procedure: 579.03 s
#
# 4 27 0.03414388544334754 0.0030026399326057557
#
# 1 3.2080186055899067
# 2 3.313358485073574
# 3 3.3661623878248363
# 4 3.4009909354563157
# 5 3.4082940003716735
# 6 3.7619564835079675
# 7 3.933508618767385
# 8 3.942200991105335
# 9 3.951691527008286
# 10 3.9526526397850774
# 11 3.9566940432306246
# 12 3.9590416495856715
# 13 3.959658171156988
# Convergence reached at 13 components
# Total time to run the procedure: 604.51 s
#
# 4 28 0.034984845922879516 0.002754254601887104
#
# 1 2.9589747809913773
# 2 3.213109932896985
# 3 3.2839426999289567
# 4 3.3195108918753604
# 5 4.026850225557336
# 6 4.035629613546264
# 7 4.045434373487129
# 8 4.047806455755545
# 9 4.052151327158753
# 10 4.0531776350881215
# 11 4.055080316876037
# 12 4.055104667447935
# 13 4.055921914201233
# Convergence reached at 13 components
# Total time to run the procedure: 639.27 s
#
# 4 29 0.034012704857722 0.0028400991937589082
#
# 1 2.572873567391802
# 2 2.807906995733281
# 3 2.8859549466983316
# 4 3.1509017368526155
# 5 3.177410679121682
# 6 3.658890162362695
# 7 3.666880233505672
# 8 3.678250957941504
# 9 3.6814259623336767
# 10 3.6830246065130248
# Convergence reached at 10 components
# Total time to run the procedure: 401.62 s
#
# 4 30 0.02983806467542962 0.0024407023001277338
#
# 1 3.1706391321661567
# 2 3.2769758800569098
# 3 3.318418661564087
# 4 3.342789260716937
# 5 3.687484000961629
# 6 3.8899512723654586
# 7 3.892397501513829
# 8 3.8949350161725973
# 9 3.895976299306678
# 10 3.8965972324448934
# Convergence reached at 10 components
# Total time to run the procedure: 449.86 s
#
# 4 31 0.03387929940160346 0.0037172148122843023
#
# 1 3.002822735079991
# 2 3.17629608644366
# 3 3.223583911452851
# 4 3.2622444719845767
# 5 3.7227140196888073
# Convergence reached at 5 components
# Total time to run the procedure: 96.00 s
#
# 4 32 0.01660238863307835 0.003804087462824758
#
# 1 2.537811870488681
# 2 2.857948318449866
# 3 3.1801111707874714
# 4 3.7173591430323256
# 5 3.73476638299339
# 6 3.744007293524574
# 7 3.750879442364802
# 8 3.75927563531099
# 9 3.761531976561178
# 10 3.7638992159506355
# 11 3.765370217690356
# 12 3.7716909720510343
# Convergence reached at 12 components
# Total time to run the procedure: 522.36 s
#
# 4 33 0.03231374147937833 0.004095243750404084
#
# 1 2.92101642038608
# 2 3.106603800060137
# 3 3.1642759171683505
# 4 3.623440482415962
# 5 3.878075545213429
# 6 3.886171697911978
# 7 3.8972452022286284
# 8 3.8983159149882796
# 9 3.901300849201079
# Convergence reached at 9 components
# Total time to run the procedure: 346.60 s
#
# 4 34 0.03271127922200508 0.0027106176085577595
#
# 1 2.961331108757309
# 2 3.1214674997436536
# 3 3.1784888295272062
# 4 3.2174922638650663
# 5 3.8664658131987735
# 6 3.878982685784926
# 7 3.887763486497031
# 8 3.899624973536165
# 9 3.9025000150194935
# 10 3.903782702935706
# 11 3.9038423903183683
# 12 3.907380439761235
# Convergence reached at 12 components
# Total time to run the procedure: 573.92 s
#
# 4 35 0.03493285994559814 0.002761420933059793
#
# 1 2.2491217536369477
# 2 2.8798837121139385
# 3 3.711436821790841
# 4 3.7574548908631424
# 5 3.7804928670023017
# 6 3.793826364355038
# Convergence reached at 6 components
# Total time to run the procedure: 186.52 s
#
# 4 36 0.02700420477033395 0.003175458675008518
#
# 1 3.3850052438157454
# 2 3.4948066879559225
# 3 3.540020654919149
# 4 3.733490993272879
# 5 3.7577272839172777
# 6 4.143796865263802
# 7 4.157386020080373
# 8 4.1587245239072
# 9 4.161009360303992
# 10 4.161650632704643
# 11 4.162254100788193
# 12 4.163821362829482
# Convergence reached at 12 components
# Total time to run the procedure: 582.98 s
#
# 4 37 0.03491858824858684 0.0027913725397666913
#
# 1 2.514548610110698
# 2 3.4256556596565098
# 3 3.7590651886059288
# 4 3.8002272200648677
# 5 3.812494807743498
# 6 3.822105622646934
# 7 3.835512048864356
# 8 3.838709586960117
# Convergence reached at 8 components
# Total time to run the procedure: 285.38 s
#
# 4 38 0.0316003716973509 0.0022959410146706338
#
# 1 2.517034524797602
# 2 3.664645133084308
# 3 3.764058029514244
# 4 3.80422835414759
# 5 3.8183001846110094
# 6 3.826296376595548
# 7 3.841238906184914
# 8 3.8447787578166266
# 9 3.8454493394015627
# Convergence reached at 9 components
# Total time to run the procedure: 356.85 s
#
# 4 39 0.03100660675888787 0.00266500384863025
#
# 1 2.807820875644691
# 2 3.0185334917251843
# 3 3.0912172202347805
# 4 3.833365224699454
# 5 3.8505640102800114
# 6 3.8561721465649055
# 7 3.8681637624706444
# 8 3.871365426840073
# 9 3.873070847058522
# 10 3.875013580812286
# Convergence reached at 10 components
# Total time to run the procedure: 380.03 s
#
# 4 40 0.03505847478015016 0.0030045348431899602
#
# 1 2.8448224314562434
# 2 3.219102170166406
# 3 3.297256296237061
# 4 4.015430816095283
# 5 4.045570870167608
# 6 4.052763932957381
# 7 4.059157215633067
# 8 4.068649209493366
# 9 4.073567771774068
# 10 4.074987147816535
# Convergence reached at 10 components
# Total time to run the procedure: 441.89 s
#
# 4 41 0.049569377611508376 0.0036016671036143773
#
# 1 3.0903187455309684
# 2 3.210960832489336
# 3 3.2600059025887824
# 4 3.2902239755248615
# 5 3.852124234890462
# 6 3.864545310074933
# 7 3.8790674293445924
# 8 3.8839446167585443
# 9 3.8888807631084794
# Convergence reached at 9 components
# Total time to run the procedure: 327.98 s
#
# 4 42 0.03312615326632485 0.0034814439558152393
#
# 1 3.074831605581981
# 2 3.181601440122971
# 3 3.2223393366519795
# 4 3.241932021771332
# 5 3.5326003232610486
# 6 3.6862461060175544
# Convergence reached at 6 components
# Total time to run the procedure: 232.59 s
#
# 4 43 0.019969533711564638 0.007680795751160952
#
# 1 2.7490974822301646
# 2 3.4774387473434865
# 3 3.786868506538951
# 4 3.832840892154385
# 5 3.8637091307971385
# Convergence reached at 10 components
# Total time to run the procedure: 455.86 s
#
# 4 44 0.027967626638651072 0.0025458592039316872
#
# 1 2.8595014072777
# 2 3.1618479991117687
# 3 3.248685813234085
# 4 3.7482648152858817
# 5 3.7604857768528714
# 6 4.017392108050642
# 7 4.027372425820028
# 8 4.031256208089093
# 9 4.033014188365249
# 10 4.03501542532864
# 11 4.036919519403117
# Convergence reached at 11 components
# Total time to run the procedure: 466.95 s
#
# 4 45 0.03813475089173582 0.0033750982551989162
#
# 1 2.6192897495783023
# 2 3.114212886079752
# 3 3.2007844587436654
# 4 3.2408834285041443
# 5 3.2523468416589556
# 6 3.7258098991260216
# 7 3.7420299416241107
# 8 3.7443746396999344
# 9 3.7468428278261876
# 10 3.7522278998424095
# Convergence reached at 10 components
# Total time to run the procedure: 400.12 s
#
# 4 46 0.028856265394901107 0.0026612588430065904
#
# 1 2.5847437816240513
# 2 2.6908409662919683
# 3 2.7303525454486306
# 4 2.7611052504015703
# 5 2.9920361720826985
# 6 3.207286094362798
# 7 3.4276312162619225
# 8 3.431517511940481
# 9 3.436142368679512
# 10 3.4375889574068075
# 11 3.4387755713782133
# 12 3.439706729182237
# 13 3.4410689134404997
# Convergence reached at 13 components
# Total time to run the procedure: 766.84 s
#
# 4 47 0.03312498754885014 0.002967498512524884
#
# 1 2.616425693879649
# 2 3.654414326691564
# 3 3.7511128141361065
# 4 3.7933320005899636
# 5 3.8106195059256507
# 6 3.8190610555777433
# 7 3.8280445377261554
# 8 3.830779439347746
# 9 3.8325996637708144
# 10 3.8328666634338013
# 11 3.8332855814962152
# Convergence reached at 11 components
# Total time to run the procedure: 508.82 s
#
# 4 48 0.0289770336104008 0.0025460963037208404
#
# 1 2.9633491460444126
# 2 3.0969250374703936
# 3 3.3420233686559375
# 4 3.7941153728315897
# 5 3.809159665307657
# 6 3.829005868416953
# 7 3.832611654514011
# 8 3.834976235494842
# Convergence reached at 8 components
# Total time to run the procedure: 309.59 s
#
# 4 49 0.03549695758480898 0.002928551284976374
#
# 1 2.390401243420318
# 2 2.743267096221961
# 3 2.8327789475390817
# 4 2.8660874196381365
# 5 3.3386564232070524
# 6 3.588083784820093
# 7 3.6084040213334947
# 8 3.618945029242319
# 9 3.625242330847206
# 10 3.630797371675259
# 11 3.6308727350371033
# 12 3.63493514052325
# Convergence reached at 12 components
# Total time to run the procedure: 502.36 s
#
# 4 50 0.034453088953415284 0.0027691594855893072
#
# 1 3.3579340255800663
# 2 3.4622405196071018
# 3 3.507546444429055
# 4 3.9222474069819806
# 5 3.937508709850828
# 6 3.9453021050179427
# 7 3.9535078708033637
# 8 3.9570816692056994
# 9 3.9591231747185547
# Convergence reached at 9 components
# Total time to run the procedure: 389.49 s
#
# 4 51 0.028900233538452426 0.0025765887380104
#
# 1 2.76958446274424
# 2 2.8745396836059123
# 3 2.9227322465219885
# 4 3.3191340624101247
# 5 3.5521651643467926
# 6 3.5652861111330183
# 7 3.568755888649278
# 8 3.57011108035973
# 9 3.572447038620377
# 10 3.57397772286522
# 11 3.575474589678333
# 12 3.576101032433497
# Convergence reached at 12 components
# Total time to run the procedure: 651.20 s
#
# 4 52 0.036062836231617115 0.002969198767680235
#
# 1 2.384261596538007
# 2 3.0440157091002895
# 3 3.1352391704335196
# 4 3.6763582242715995
# Convergence reached at 4 components
# Total time to run the procedure: 70.19 s
#
# 4 53 0.036496109689054035 0.005057228887035194
#
# 1 3.2531089924842527
# 2 3.363864370685612
# 3 3.405300866479101
# 4 3.433631058630354
# 5 3.4432648097731255
# 6 3.456904603239264
# 7 3.874834927051071
# 8 3.880152925405666
# 9 3.8814199465553063
# 10 3.8814341462283353
# 11 3.8822810570508017
# Convergence reached at 11 components
# Total time to run the procedure: 596.12 s
#
# 4 54 0.030396421187260866 0.00425523953172139
#
# 1 2.336891408565189
# 2 2.7353473087640983
# 3 2.809695048503879
# 4 2.8478919500787483
# 5 3.6111018486583397
# Convergence reached at 5 components
# Total time to run the procedure: 86.45 s
#
# 4 55 0.025397499986533068 0.005014772146939379
#
# 1 2.6609525470929656
# 2 2.767134918982322
# 3 2.8118501169366206
# 4 2.827870665257945
# 5 2.8376590626996863
# 6 2.8530570888070304
# 7 2.8560801878591024
# 8 3.0446797643918457
# Convergence reached at 8 components
# Total time to run the procedure: 366.95 s
#
# 4 56 0.017864652803719957 0.005515729275104074
#
# 1 2.443056495101494
# 2 3.5140025274375835
# 3 3.611886256960533
# 4 3.652926746856467
# 5 3.6696935055277553
# 6 3.6815771414260383
# 7 3.6937006427131553
# 8 3.6963812261867446
# 9 3.6983947177005922
# 10 3.7012980274007448
# Convergence reached at 10 components
# Total time to run the procedure: 428.82 s
#
# 4 57 0.03484974223914679 0.0026013869506161954
#
# 1 -0.43820252089481043
# 2 0.6554267215362312
# 3 0.7440248664523711
# 4 0.7896577855569555
# 5 0.8169648083370888
# 6 0.8337918986030713
# 7 1.012451074064417
# 8 1.2116638209664001
# 9 1.4012033652301559
# 10 1.4112405456729775
# 11 1.4163298840966272
# 12 1.4196903716579072
# 13 1.4212263690593112
# 14 1.4241452801497605
# 15 1.424312066541561
# Convergence reached at 15 components
# Total time to run the procedure: 690.57 s
#
# 4 58 0.044982175431680024 0.003305222419698824
#
# 1 2.665185394655332
# 2 2.7722969795160544
# 3 2.826071711017852
# 4 2.8600500682152545
# 5 3.056626109244059
# 6 3.4377299797127905
# 7 3.444088579041637
# 8 3.448483046387006
# 9 3.449878737307419
# 10 3.451288030760287
# 11 3.4527841161494037
# 12 3.4577045323669573
# Convergence reached at 12 components
# Total time to run the procedure: 562.65 s
#
# 4 59 0.04294442850027493 0.0026502773942170344
#
# 1 2.80148532736418
# 2 2.907832851765566
# 3 2.955834046290875
# 4 2.9943396895137764
# 5 3.0085975901259343
# 6 3.023400327344947
# 7 3.1954648954498333
# 8 3.2090271184612185
# 9 3.3738015912104733
# 10 3.552464990883062
# 11 3.554023124728563
# Convergence reached at 11 components
# Total time to run the procedure: 532.49 s
#
# 4 60 0.036601004311797365 0.007349244331609953
#
# 1 3.402888591991783
# 2 3.513376800845581
# 3 3.5567696251690144
# 4 3.584867707309236
# 5 3.5963898589786694
# 6 3.866128769071007
# 7 4.013695182960642
# 8 4.016605199060159
# 9 4.01841149649612
# 10 4.019757586360082
# Convergence reached at 10 components
# Total time to run the procedure: 409.66 s
#
# 4 61 0.03316582565445933 0.004693627929964791
#
# 1 3.196860026159508
# 2 3.303520527957399
# 3 3.3430247661903505
# 4 3.3703944316142915
# 5 3.5139387659866856
# 6 3.8202225984752842
# 7 3.8356959858170954
# 8 3.8378017992943625
# 9 3.840667531547284
# 10 3.843230040139906
# Convergence reached at 10 components
# Total time to run the procedure: 460.94 s
#
# 4 62 0.028934161814538922 0.0023319847337608243
#
# 1 2.4740084899385084
# 2 3.0383739782892634
# 3 3.5910934318547105
# 4 3.634916753653576
# 5 3.6625572453881357
# 6 3.6755628393261475
# 7 3.6783937308074806
# 8 3.6824604242405403
# 9 3.6897151048977417
# Convergence reached at 9 components
# Total time to run the procedure: 306.28 s
#
# ...
# 5 3.97159209105055
# 6 3.9839261610257943
# 7 3.994262108421139
# 8 3.9945532160438817
# 9 3.999863307998568
# 10 4.0033470759890735
# 11 4.003908419981697
# Convergence reached at 11 components
# Total time to run the procedure: 524.46 s
#
# 4 100 0.0323493471650291 0.0027377983093449724
#
# 1 2.6043249985608736
# 2 2.885816150336744
# 3 3.1831193548293215
# 4 3.6821155032061372
# 5 3.708815254993944
# 6 3.7177600573603224
# 7 3.7226099435417304
# 8 3.730051582405146
# 9 3.7336429457836005
# 10 3.7376009703610475
# 11 3.7400132288704255
# Convergence reached at 11 components
# Total time to run the procedure: 481.07 s
#
# 4 101 0.031831501166729795 0.002523916887528917
#
# 1 2.7877390999968266
# 2 2.894293580352574
# 3 2.9392164333182245
# 4 2.9629052735581443
# 5 3.5847350993689826
# 6 3.5930195398868694
# 7 3.5991473141568924
# 8 3.6053267277266774
# 9 3.606366463813639
# 10 3.6072553420901348
# Convergence reached at 10 components
# Total time to run the procedure: 468.21 s
#
# 4 102 0.028038819615257542 0.002593458609175768
#
# 1 2.5433144994700054
# 2 2.808467846712176
# 3 3.5894576473061943
# 4 3.6284343696344785
# 5 3.6428131020991246
# 6 3.655924361620635
# 7 3.6664352625981045
# 8 3.6678637935479075
# 9 3.66978147514021
# 10 3.670038777884327
# 11 3.670865348563394
# 12 3.6729043547204294
# Convergence reached at 12 components
# Total time to run the procedure: 584.84 s
#
# 4 103 0.03250230782146918 0.0028918799199330486
#
# 1 2.714864783479832
# 2 3.4024896785897263
# 3 3.5059479641055185
# 4 3.771839893550362
# 5 3.8063505280547645
# 6 3.8111981347632073
# 7 3.8212004852422194
# 8 3.824610544997095
# 9 3.827724757717597
# 10 3.8295304656900195
# 11 3.8318990546737166
# 12 3.8324260609088623
# 13 3.8329861971700887
# Convergence reached at 13 components
# Total time to run the procedure: 648.48 s
#
# 4 104 0.03382463839573259 0.0038721714165902265
#
# 1 3.149185175598241
# 2 3.262625041309055
# 3 3.312132064455266
# 4 3.337157943649334
# 5 3.663190207803851
# 6 3.8208970940060785
# 7 3.833472257984725
# 8 3.835056312492704
# 9 3.8386286806200682
# 10 3.839490572064761
# 11 3.83998118830786
# 12 3.8413148671897352
# 13 3.842653857719423
# 14 3.8427459897732863
# Convergence reached at 14 components
# Total time to run the procedure: 868.12 s
#
# 4 105 0.03881061386230913 0.0028472026730283614
#
# 1 2.663175376998553
# 2 2.87648000713529
# 3 2.9489285337098856
# 4 3.6606991802577533
# Convergence reached at 4 components
# Total time to run the procedure: 79.87 s
#
# 4 106 0.022336957011752062 0.004456411284458792
#
# 1 2.336090776147264
# 2 3.5332390650702727
# 3 3.6312999053810238
# 4 3.671150366178995
# 5 3.693226163806211
# 6 3.70451277678565
# 7 3.716658095869215
# 8 3.7200788454872122
# 9 3.7206917147648206
# Convergence reached at 9 components
# Total time to run the procedure: 376.99 s
#
# 4 107 0.04237774874617557 0.0036403612281352437
#
# 1 2.6007995267315116
# 2 3.5467365664059725
# 3 3.6446591242806363
# 4 3.685025032727596
# 5 3.696697739685668
# 6 3.707782882070307
# 7 3.7166430300056414
# 8 3.7187525552629164
# 9 3.719292576350371
# 10 3.7212203577878804
# Convergence reached at 10 components
# Total time to run the procedure: 432.00 s
#
# 4 108 0.02879085652652656 0.0030972109396770696
#
# 1 3.329092976266969
# 2 3.431674268016868
# 3 3.473650644861723
# 4 3.4859009518009576
# 5 3.646589695021783
# 6 3.6548771398814384
# 7 3.808036903600476
# 8 3.956275565494529
# 9 3.9566152378640616
# Convergence reached at 9 components
# Total time to run the procedure: 491.92 s
#
# 4 109 0.03221637626595761 0.004121807290163617
#
# 1 2.829462926607228
# 2 2.9342051300659517
# 3 2.976617647728728
# 4 2.9882978012831756
# 5 3.0025478618372943
# 6 3.345963879050301
# 7 3.50853082090678
# Convergence reached at 7 components
# Total time to run the procedure: 361.35 s
#
# 4 110 0.030254651094336373 0.007491576009212955
#
# 1 2.594893102435007
# 2 2.83053786334106
# 3 3.124964034074709
# 4 3.389942490630118
# 5 3.6256133924482383
# 6 3.632981124822044
# 7 3.64255709652846
# 8 3.651167053993723
# 9 3.659368098326794
# 10 3.6629689567414423
# 11 3.667322733558026
# Convergence reached at 11 components
# Total time to run the procedure: 486.13 s
#
# 4 111 0.037229008472975125 0.0031177289325094535
#
# 1 2.4694773300654798
# 2 3.2158528008077156
# 3 3.772538158498834
# 4 3.8186146479587584
# 5 3.8424828509967885
# 6 3.851164967451052
# 7 3.8580217549295077
# 8 3.860337664408038
# 9 3.8654789715489106
# Convergence reached at 9 components
# Total time to run the procedure: 341.37 s
#
# 4 112 0.029273624503018694 0.002429924698913126
#
# 1 2.345856806827656
# 2 2.734835543198491
# 3 3.0546728145732764
# 4 3.5721682428898496
# 5 3.6129007947609915
# 6 3.623185914618233
# 7 3.6250493153714256
# 8 3.6406619659495125
# 9 3.645176986210048
# Convergence reached at 9 components
# Total time to run the procedure: 342.01 s
#
# 4 113 0.03295290503313355 0.0028383022938295623
#
# 1 2.5386578121542382
# 2 3.131665295681089
# Convergence reached at 2 components
# Total time to run the procedure: 22.47 s
#
# 4 114 0.02435774281587646 0.020965739683081127
#
# 1 2.3201175350522383
# 2 2.953592144547803
# 3 3.039110069175347
# 4 3.078260479983873
# 5 3.347422116507566
# 6 3.8639157789618217
# 7 3.872719618456621
# 8 3.8813382073427896
# 9 3.8847010499620716
# 10 3.8882540122814504
# 11 3.8899378663821422
# 12 3.8921343921324003
# 13 3.893066236533171
# Convergence reached at 13 components
# Total time to run the procedure: 595.54 s
#
# 4 115 0.036344971720276356 0.002901622910606824
#
# 1 3.450458727241642
# 2 3.5575069265047508
# 3 3.608102320119262
# 4 3.637470773391828
# 5 3.64373452606133
# 6 3.656523074411011
# 7 3.661367576145009
# 8 3.8065909253876034
# 9 4.0767662973926075
# Convergence reached at 9 components
# Total time to run the procedure: 403.85 s
#
# 4 116 0.021557429985087764 0.00757291089680523
#
# 1 2.840090727697806
# 2 2.943179068788064
# 3 2.988304996150943
# 4 3.001349328800393
# 5 3.0159336659942695
# 6 3.0213040863344927
# 7 3.0310087797753105
# 8 3.0311211557729947
# Convergence reached at 8 components
# Total time to run the procedure: 416.00 s
#
# 4 117 0.012427700297909324 0.003446831618376515
#
# 1 2.9852742076074805
# 2 3.088284523012879
# 3 3.1304864184158987
# 4 3.1576704581705157
# 5 3.1715019192428646
# 6 3.1759263080736546
# 7 3.3254510663349266
# 8 3.3457306525763326
# 9 3.491964493225096
# Convergence reached at 9 components
# Total time to run the procedure: 366.35 s
#
# 4 118 0.0223631873540315 0.00807009539498963
#
# 1 2.6599460459471804
# 2 2.7821513618526286
# 3 2.849369259489374
# 4 2.8855113150495413
# 5 3.12682174329703
# 6 3.5856880311144455
# 7 3.5901222412709757
# 8 3.601058245346272
# 9 3.6035724159191904
# 10 3.6058185043270394
# Convergence reached at 10 components
# Total time to run the procedure: 414.98 s
#
# 4 119 0.03432030166252838 0.00301387003875459
#
# 1 2.4903650665929113
# 2 3.0019367532569334
# 3 3.8068511495722674
# 4 3.852792162046891
# 5 3.8706101953636725
# 6 3.878774506992777
# 7 3.8868292107872287
# 8 3.8902573699049587
# 9 3.890905826084083
# 10 3.896768103616941
# Convergence reached at 10 components
# Total time to run the procedure: 400.98 s
#
# 4 120 0.02964163404840642 0.006509659047048338
#
# 1 3.1090787908869397
# 2 3.214923039349255
# 3 3.2572201275810255
# 4 3.276079251706678
# 5 3.889773646473518
# 6 3.9038296870244014
# 7 3.9162388408373077
# Convergence reached at 7 components
# Total time to run the procedure: 263.63 s
#
# 4 121 0.02186470727137294 0.0028691445046668913
#
# 1 3.0840131158176405
# 2 3.188723514366903
# 3 3.2327716939844215
# 4 3.256779954117348
# 5 3.2646798514418407
# 6 3.2775947243127277
# 7 3.2804620973863865
# 8 3.6262553003651004
# 9 3.801848478645434
# 10 3.8035816528483406
# 11 3.807189118627486
# 12 3.8073147284660407
# 13 3.8076772142724153
# 14 3.808245897517665
# Convergence reached at 14 components
# Total time to run the procedure: 859.16 s
#
# 4 122 0.03607308071787522 0.0037136046714661454
#
# 1 2.974783287929485
# 2 3.091174228972404
# 3 3.1457441007068425
# 4 3.7672158409200454
# 5 3.7892347248419807
# 6 3.802176154648348
# 7 3.806170216267572
# 8 3.807182528141817
# 9 3.809309808285725
# Convergence reached at 9 components
# Total time to run the procedure: 450.10 s
#
# 4 123 0.03511815350915468 0.0033919662768267834
#
# 1 -1.5718981199823332
# 2 -1.4666391881841443
# 3 -1.365038570488909
# 4 -1.2947892011536843
# 5 -1.2827271920510388
# 6 -1.2735251642696055
# 7 -1.0572402652031692
# 8 -1.0461213432014724
# 9 -1.0458903988396289
# 10 -1.042495224128186
# 11 -0.8135038372537583
# 12 -0.803135161975104
# 13 -0.5746474389183663
# Convergence reached at 13 components
# Total time to run the procedure: 850.16 s
#
# 4 124 0.03709947354988705 0.006116994942917286
#
# 1 2.6880710615704593
# 2 3.8495781864584795
# 3 3.948582667027613
# 4 3.9923923415490665
# 5 4.011918905449073
# 6 4.021326149827819
# 7 4.033184294533648
# 8 4.038464755157642
# 9 4.039383206028089
# 10 4.040247602097178
# 11 4.046908870433312
# Convergence reached at 11 components
# Total time to run the procedure: 571.63 s
#
# 4 125 0.02619694143332453 0.005970436153109046
#
# 1 2.851713025300979
# 2 2.955748713572003
# 3 2.996954790364402
# 4 3.021636739064856
# 5 3.0296047593052404
# 6 3.585788533795135
# 7 3.5936434776868755
# 8 3.5968825200879535
# 9 3.6038173405876326
# 10 3.6061010887895524
# 11 3.60701881673682
# 12 3.6099823835785863
# Convergence reached at 12 components
# Total time to run the procedure: 677.11 s
#
# 4 126 0.03010098162907918 0.0025828076472181687
#
# 1 2.819364685939983
# 2 3.0818610129206285
# 3 3.158952641434111
# 4 3.1911371348820587
# 5 3.439981441997297
# 6 3.6880140634310727
# 7 3.9175829558657824
# 8 3.925512730624165
# Convergence reached at 8 components
# Total time to run the procedure: 303.97 s
#
# 4 127 0.03196279842997045 0.003455450913172401
#
# 1 -2.830033652171688
# 2 -2.30295365251313
# 3 -2.1918650565665594
# 4 -1.3711452432416902
# 5 -1.3422908650310241
# 6 -1.306840815026267
# 7 -1.2923394952641474
# 8 -1.2838922934926427
# 9 -1.2751759961185785
# 10 -1.2735225086343223
# 11 -1.2713617996528352
# 12 -1.2677958577915922
# 13 -1.2640880102092764
# 14 -1.262579952538206
# Convergence reached at 14 components
# Total time to run the procedure: 596.19 s
#
# 5 0 0.28611428457823357 0.008842675198629926
#
# 1 -3.0050938312074993
# 2 -1.7501422812384781
# 3 -1.2191353646117762
# 4 -1.1512445847298707
# 5 -1.119509343080761
# 6 -1.0957267536495798
# Convergence reached at 6 components
# Total time to run the procedure: 118.53 s
#
# 5 1 0.2301633526259524 0.009869790813172866
#
# 1 -2.1405501253464756
# 2 -1.8053545572434315
# 3 -1.699892356922896
# 4 -0.9903516480152302
# 5 -0.9711641713449034
# 6 -0.9467952153226822
# 7 -0.932752435621978
# 8 -0.9304579666336537
# 9 -0.9271261691581175
# Convergence reached at 9 components
# Total time to run the procedure: 284.49 s
#
# 5 2 0.2762856716852529 0.0109285022438654
#
# 1 -2.0746092232424918
# 2 -1.8059327228370716
# 3 -1.5313773516518976
# 4 -1.0719914105488177
# 5 -1.0243508839208249
# 6 -1.0130833912211157
# 7 -1.009140174718842
# 8 -1.0072071479199929
# 9 -1.005779807091881
# 10 -1.0029107390973502
# 11 -0.9989245693062676
# Convergence reached at 11 components
# Total time to run the procedure: 411.73 s
#
# 5 3 0.23958708755379796 0.008880967513970628
#
# 1 -1.9637056009908802
# 2 -1.6966185291837217
# 3 -1.5927608326220026
# 4 -1.5513051430144176
# 5 -0.8823983409194898
# 6 -0.8411686963736296
# 7 -0.8209801950956677
# Convergence reached at 7 components
# Total time to run the procedure: 165.88 s
#
# 5 4 0.24113590745850894 0.007361674679428789
#
# 1 -2.8130356003503842
# 2 -2.3857968814020993
# 3 -1.4783394649399009
# 4 -1.4190095167841144
# 5 -1.395122079308064
# 6 -1.362070482874534
# 7 -1.3579775340325977
# 8 -1.3571022085882243
# 9 -1.3536740798779958
# 10 -1.3478656253130483
# 11 -1.344942609647654
# 12 -1.342177681581324
# 13 -1.3420269105448475
# 14 -1.339884965383573
# Convergence reached at 14 components
# Total time to run the procedure: 607.75 s
#
# 5 5 0.26077803276888495 0.00984308764831511
#
# 1 -2.1767450135585933
# 2 -1.91485371918091
# 3 -1.8554515823972324
# 4 -1.1793208866481635
# 5 -1.1460230311714492
# 6 -1.110337183159019
# 7 -1.107577181125861
# 8 -1.104038472154074
# 9 -1.1019110709515507
# 10 -1.0972940371036428
# Convergence reached at 10 components
# Total time to run the procedure: 344.88 s
#
# 5 6 0.24457888672978714 0.009566470027209735
#
# 1 -2.9456349066679244
# 2 -2.5374434917365813
# 3 -2.198755626793798
# 4 -1.5979735291743393
# 5 -1.551669724185997
# 6 -1.51213258485145
# 7 -1.4907121244974728
# Convergence reached at 7 components
# Total time to run the procedure: 148.52 s
#
# 5 7 0.26703818153251135 0.007964361289113549
#
# 1 -2.7692107690928283
# 2 -1.3789804849279788
# 3 -1.138182939937307
# 4 -1.056497848679696
# 5 -1.0312818678037008
# Convergence reached at 5 components
# Total time to run the procedure: 67.36 s
#
# 5 8 0.24225134247625474 0.011528479293384733
#
# 1 -2.9043286643446735
# 2 -2.5241043457230554
# 3 -2.2343746842408057
# 4 -1.6331119108504526
# Convergence reached at 4 components
# Total time to run the procedure: 49.79 s
#
# 5 9 0.21763176577530963 0.013565463551521646
#
# 1 -3.052200714078594
# 2 -2.3404070895287723
# 3 -1.384522765374393
# 4 -1.3117259332975841
# 5 -1.288530201290526
# 6 -1.2547753508717516
# 7 -1.248775585617597
# 8 -1.2453253418038035
# 9 -1.2401376792744088
# 10 -1.2357832766485257
# 11 -1.2346782404067531
# 12 -1.233628653438975
# Convergence reached at 12 components
# Total time to run the procedure: 364.69 s
#
# 5 10 0.24864648248355226 0.008244249722702199
#
# 1 -7.130260218506957
# 2 -6.769688987254917
# 3 -6.275694630883138
# 4 -5.566332276288875
# Convergence reached at 4 components
# Total time to run the procedure: 47.59 s
#
# 5 11 0.2034997916994711 0.006378777991109269
#
# 1 -3.002778651660234
# 2 -2.493932228094614
# 3 -1.5830432466764168
# 4 -1.5214690326032418
# 5 -1.482376001699793
# 6 -1.4600958745819534
# 7 -1.4507857052629725
# 8 -1.449947989873686
# 9 -1.445593897975236
# 10 -1.4431825724094915
# 11 -1.4407271220079505
# 12 -1.435530186700701
# Convergence reached at 12 components
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15092/734553196.py in <module>
#      58                                 tol=tol, max_iter=10000,
#      59                                 random_state=best_seed, weights_init=w_init,
# ---> 60                                 means_init=m_init, precisions_init=p_init).fit(X_bs)
#      61
#      62                     # in case of "warm start", uncomment next line
#
# ~/.conda/envs/MI/lib/python3.7/site-packages/sklearn/mixture/_base.py in fit(self, X, y)
#     196             The fitted mixture.
#     197         """
# --> 198         self.fit_predict(X, y)
#     199         return self
#     200
#
# /tmp/ipykernel_15092/1682740032.py in fit_predict(self, X, y)
#     272                 prev_lower_bound = lower_bound
#     273
# --> 274                 log_prob_norm, log_resp = self._e_step(X)
#     275                 self._m_step(X, log_resp)
#     276                 lower_bound = self._compute_lower_bound(log_resp, log_prob_norm)
#
# ~/.conda/envs/MI/lib/python3.7/site-packages/sklearn/mixture/_base.py in _e_step(self, X)
#     310             the point of each sample in X.
#     311         """
# --> 312         log_prob_norm, log_resp = self._estimate_log_prob_resp(X)
#     313         return np.mean(log_prob_norm), log_resp
#     314
#
# ~/.conda/envs/MI/lib/python3.7/site-packages/sklearn/mixture/_base.py in _estimate_log_prob_resp(self, X)
#     529         """
#     530         weighted_log_prob = self._estimate_weighted_log_prob(X)
# --> 531         log_prob_norm = logsumexp(weighted_log_prob, axis=1)
#     532         with np.errstate(under="ignore"):
#     533             # ignore underflow
#
# ~/.conda/envs/MI/lib/python3.7/site-packages/scipy/special/_logsumexp.py in logsumexp(a, axis, b, keepdims, return_sign)
#     112     # suppress warnings about log of zero
#     113     with np.errstate(divide='ignore'):
# --> 114         s = np.sum(tmp, axis=axis, keepdims=keepdims)
#     115         if return_sign:
#     116             sgn = np.sign(s)
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# ~/.conda/envs/MI/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2258
#    2259     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2260                           initial=initial, where=where)
#    2261
#    2262
#
# ~/.conda/envs/MI/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %%
np.save('./MI_all_4.npy', MI_all[3:4])

# %%
MI_all[3:4]
# Out:
# array([[[0.03768166, 0.01931102, 0.01260508, ..., 0.02526271,
#          0.02114927, 0.0157036 ],
#         [0.06041584, 0.04397468, 0.0558428 , ..., 0.0498513 ,
#          0.04768302, 0.05081441],
#         [0.01230756, 0.01869815, 0.01799742, ..., 0.01458915,
#          0.02004483, 0.0131966 ],
#         ...,
#         [0.01003754, 0.01950905, 0.00705856, ..., 0.01034655,
#          0.00729047, 0.00802851],
#         [0.01922445, 0.02529365, 0.02544357, ..., 0.02230932,
#          0.02279015, 0.02170192],
#         [0.02768948, 0.02491218, 0.0237776 , ..., 0.02743542,
#          0.02203092, 0.03457058]]])
