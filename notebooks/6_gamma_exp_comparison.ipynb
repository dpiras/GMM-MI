# %% [markdown]
# In this notebook, we compare GMM-MI with the [KSG estimator](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.mutual_info_regression.html) and the [MINE estimator](https://github.com/gtegner/mine-pytorch) on a gamma-exponential distribution with varying free parameter $\alpha$. To run this notebook you will need to install the MINE package following the instructions in the repository, which we report here. The cloning can be avoided if you use the folder already cloned for you in this repo.
# ```
# git clone git@github.com:gtegner/mine-pytorch.git
# cd mine-pytorch
# pip install -e .
# ```
# (note that to avoid conflicts you should also edit the setup file, changing `scikit_learn==0.22.1` to `scikit_learn>=0.22.1`). Note the MINE results are not "reproducible", in the sense that the seed is not fixed.

# %% [markdown]
# ### Import packages

# %%
import numpy as np
import yaml
import time
import matplotlib.pyplot as plt
# GMM-MI
from gmm_mi.mi import EstimateMI
from gmm_mi.utils.analytic_MI import calculate_MI_gammaexp_analytical
# KSG
from sklearn.feature_selection import mutual_info_regression
# MINE
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import TensorDataset, DataLoader
from mine.models.mine import MutualInformationEstimator
from pytorch_lightning import Trainer
import logging
logging.getLogger().setLevel(logging.ERROR)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
num_gpus = 1 if device=='cuda' else 0
# Out:
# Device: cpu

# %% [markdown]
# ### Calculate the true MI of the synthetic models

# %%
alphas = np.logspace(-1, 2, 20)
N = int(2e2)
# fix random state for stability across runs
random_state = 30
random_gen = np.random.default_rng(random_state)

analytic = []
for alpha in alphas:
    analytic.append(calculate_MI_gammaexp_analytical(alpha))

# %% [markdown]
# ### KSG

# %%
knn_estimates = []
n_neighbors = 1 # keep minimum bias

initial_time = time.time()

for alpha in alphas:
    x_samples = random_gen.gamma(alpha, 1, N)
    # then for each x, we sample from an exp
    y_samples = random_gen.exponential(scale = 1/x_samples)
    X = np.stack((np.log(x_samples), np.log(y_samples)), axis=0).T
    knn_estimates.append(mutual_info_regression(X[:, 0].reshape(-1, 1), X[:, 1], 
                                                n_neighbors=n_neighbors))

ksg_time = time.time()-initial_time    
    
print(f'Total time for KSG: {ksg_time:.3f} s')
# Out:
# Total time for KSG: 0.040 s

# %% [markdown]
# ### MINE

# %%
mine_estimates = []

dim = 1
lr = 1e-3
epochs = 50
batch_size = 64
loss_type = ['mine']  # mine, mine_biased, fdiv
loss = loss_type[0]

initial_time = time.time()

for alpha in alphas:
    x_samples = random_gen.gamma(alpha, 1, N)
    # then for each x, we sample from an exp
    y_samples = random_gen.exponential(scale = 1/x_samples)
    X = np.stack((np.log(x_samples), np.log(y_samples)), axis=0).T

    N = X.shape[0]
    train_size = int(0.9 * N)
    test_size = N - train_size

    train_set, test_set = train_test_split(X, test_size=0.1, random_state=42)

    tensor_x = torch.Tensor(train_set[:, :1]) # transform to torch tensor
    tensor_y = torch.Tensor(train_set[:, 1:]) # transform to torch tensor
    my_dataset = TensorDataset(tensor_x,tensor_y)
    train_loader = torch.utils.data.DataLoader(my_dataset, batch_size=batch_size, shuffle=True)

    tensor_x = torch.Tensor(test_set[:, :1]) # transform to torch tensor
    tensor_y = torch.Tensor(test_set[:, 1:]) # transform to torch tensor
    my_dataset = TensorDataset(tensor_x,tensor_y)
    test_loader = torch.utils.data.DataLoader(my_dataset, batch_size=batch_size, shuffle=True)

    kwargs = {
        'lr': lr,
        'batch_size': batch_size,
        'train_loader': train_loader,
        'test_loader': test_loader,
        'alpha': 1.
    }

    model = MutualInformationEstimator(
        dim, dim, loss=loss, **kwargs).to(device)
    
    trainer = Trainer(max_epochs=epochs, early_stop_callback=False, gpus=num_gpus)
    trainer.fit(model)
    trainer.test()

    mine_estimates.append(model.avg_test_mi)

mine_time = time.time()-initial_time    
    
print(f'Total time for MINE: {mine_time:.3f} s')
# Out:
# 2022-08-21 21:01:52.235013: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/openmpi/lib
# 2022-08-21 21:01:52.235037: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 63.92batch/s, batch_idx=2, loss=-1.663, loss_tqdm=0.502, mi=-.502, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 354.40batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 65.44batch/s, batch_idx=2, loss=-1.409, loss_tqdm=-1.44, mi=1.44, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 371.36batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 65.59batch/s, batch_idx=2, loss=-1.200, loss_tqdm=-1.7, mi=1.7, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 236.68batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 64.91batch/s, batch_idx=2, loss=-0.824, loss_tqdm=-.982, mi=0.982, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 215.35batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 62.37batch/s, batch_idx=2, loss=-0.856, loss_tqdm=-.954, mi=0.954, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 370.26batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 62.80batch/s, batch_idx=2, loss=-0.564, loss_tqdm=-.387, mi=0.387, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 244.95batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 62.07batch/s, batch_idx=2, loss=-0.384, loss_tqdm=-.555, mi=0.555, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 361.40batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 65.07batch/s, batch_idx=2, loss=-0.336, loss_tqdm=-.527, mi=0.527, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 252.59batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 62.02batch/s, batch_idx=2, loss=-0.255, loss_tqdm=-.322, mi=0.322, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 367.75batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 65.05batch/s, batch_idx=2, loss=-0.167, loss_tqdm=-.241, mi=0.241, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 293.97batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 63.06batch/s, batch_idx=2, loss=-0.072, loss_tqdm=0.0264, mi=-.0264, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 407.90batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 61.89batch/s, batch_idx=2, loss=-0.095, loss_tqdm=-.0995, mi=0.0995, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 236.57batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 64.94batch/s, batch_idx=2, loss=-0.067, loss_tqdm=-.206, mi=0.206, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 250.20batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 61.70batch/s, batch_idx=2, loss=-0.050, loss_tqdm=-.149, mi=0.149, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 381.00batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 64.52batch/s, batch_idx=2, loss=-0.009, loss_tqdm=-.0122, mi=0.0122, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 288.64batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 64.19batch/s, batch_idx=2, loss=-0.015, loss_tqdm=-.0151, mi=0.0151, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 226.78batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 61.03batch/s, batch_idx=2, loss=-0.004, loss_tqdm=-.0175, mi=0.0175, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 371.07batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 65.41batch/s, batch_idx=2, loss=-0.002, loss_tqdm=-.00415, mi=0.00415, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 418.38batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 62.16batch/s, batch_idx=2, loss=-0.002, loss_tqdm=-.0021, mi=0.0021, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 356.40batch/s]
# Epoch 50: 100%|██████████| 3/3 [00:00<00:00, 63.43batch/s, batch_idx=2, loss=-0.001, loss_tqdm=-.00197, mi=0.00197, v_num=412032]
# Testing: 100%|██████████| 3/3 [00:00<00:00, 396.04batch/s]
# Total time for MINE: 50.223 s

# %% [markdown]
# ### GMM-MI

# %%
all_MI_estimates = np.zeros((len(alphas), 2))

# load parameters from yaml file and assign them to variables
# not the cleanest and safest way, but it should work
with open('./config_parameters_5-8.yml', 'rb') as f:
    conf = yaml.safe_load(f.read())
locals().update(conf)

initial_time = time.time()

for r, alpha in enumerate(alphas):
    x_samples = random_gen.gamma(alpha, 1, N)
    # then for each x, we sample from an exp
    y_samples = random_gen.exponential(scale = 1/x_samples)
    X = np.stack((np.log(x_samples), np.log(y_samples)), axis=0).T

    MI_mean, MI_std = EstimateMI(n_folds=n_folds, n_inits=n_inits, init_type=init_type, reg_covar=reg_covar, 
                             tol=tol, max_iter=max_iter, bootstrap=bootstrap, n_bootstrap=n_bootstrap, 
                             MC_samples=MC_samples, metric_method=metric_method, patience=patience, 
                             verbose=verbose, return_lcurves=return_lcurves).fit(X)   

    # store results
    all_MI_estimates[r, 0] = MI_mean
    all_MI_estimates[r, 1] = MI_std

gmm_mi_time = time.time()-initial_time
print(f'Total time for GMM: {gmm_mi_time:.3f} s')
# Out:
# Total time for GMM: 45.329 s

# %% [markdown]
# ### Plot results

# %%
# let's plot all of this
fig, ax = plt.subplots(1, 1, figsize=(12, 7))

sigmas = 2
lw = 3

ax.tick_params(axis='both', which='major', labelsize=22, size=10)
ax.tick_params(axis='both', which='minor', labelsize=22, size=5)
ax.plot(alphas, knn_estimates, c='tomato', lw=lw, label=f'KSG ({ksg_time/len(alphas):.3f} s, single estimate)')
ax.plot(alphas, mine_estimates, c='darkgreen', ls='-.', lw=lw, label=f'MINE ({mine_time/len(alphas):.1f} s, single estimate)')
ax.plot(alphas, all_MI_estimates[:, 0], color='grey', alpha=0.8)
ax.fill_between(alphas, all_MI_estimates[:, 0] - sigmas*all_MI_estimates[:, 1], 
                all_MI_estimates[:, 0]+sigmas*all_MI_estimates[:, 1], 
                color='grey', alpha=0.8, label=f'GMM-MI ({gmm_mi_time/len(alphas):.1f} s, full distribution)')
ax.plot(alphas, analytic, ls='--', c='black', lw=lw, label='Ground truth')

handles, labels = ax.get_legend_handles_labels()
i1, i2 = -1, -2
handles[i1], handles[i2] = handles[i2], handles[i1] 
labels[i1], labels[i2] = labels[i2], labels[i1] 

ax.legend(handles, labels, fontsize=25, frameon=False)
        
ax.set_xlabel(r'$\alpha$', fontsize=30)
ax.set_ylabel('Mutual information [nats]', fontsize=25);

ax.set_xscale('log')

plt.savefig('./figures/gamma_exp_comparison.pdf',  bbox_inches='tight');
